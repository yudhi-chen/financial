# %% [markdown]
# # Analysis single stock market price using yfinance module

# %%
# Upgrade the module 
# Ref: https://stackoverflow.com/questions/68320184/yfinance-returning-error-when-downloading-data
#!pip install yfinance --upgrade --no-cache-dir

# %%
import yfinance as yf
import pandas as pd

import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Set any float number precision 2 decimal points
pd.set_option('precision', 2)

# %%
start_date = '2016-01-01'
end_date = '2021-09-25'

# %%
# Extract stock price only 'Adj Close' and 'Volume'

df = yf.download('BTC-USD',start=start_date,end=end_date,interval='1d',rounding=1)[['Adj Close', 'Volume']]#.to_frame()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.tail(5)
# Out:
#             Adj Close       Volume  AdjC_cum  AdjC_pct
# Date
# 2021-09-20   42843.80  43909845642  42413.23     -9.34
# 2021-09-21   40693.68  48701090088  40263.11     -5.02
# 2021-09-22   43574.51  38139709246  43143.94      7.08
# 2021-09-23   44895.10  34244064430  44464.53      3.03
# 2021-09-24   42839.75  42839345714  42409.18     -4.58

# %%
# Define function for style
def above_zero(val):
  color = 'green' if val > 0 else 'red'
  return 'color: %s' % color

# %%
# Copy file to prevent A value is trying to be set on a copy of a slice from a DataFrame
df = df.copy()

# Find Adjusted Close price difference and cumulative sum
df.loc[:,'AdjC_cum'] = df.loc[:,'Adj Close'] - df.loc[:,'Adj Close'].shift(periods = 1)
df.loc[:,'AdjC_cum'] = df.loc[:,'AdjC_cum'].cumsum()

# Similar method to Find Adjusted Close price difference and cumulative sum in a single command diff
#df.loc[:,'AdjC_cum1'] = df.loc[:,'Adj Close'].diff().cumsum()

# Find Adjusted Close price percentage
df.loc[:,'AdjC_pct'] = df.loc[:,'Adj Close'].pct_change()*100

# Fill NaN value with zero
df.fillna(value = 0, inplace = True)

# %%
df.shape
# Out:
# (2091, 4)

# %%
df['AdjC_pct'].value_counts(bins = 20).to_frame().nlargest(5,'AdjC_pct')
# Out:
#                   AdjC_pct
# (-2.84, 0.28]          777
# (0.28, 3.401]          699
# (3.401, 6.522]         205
# (-5.961, -2.84]        185
# (-9.082, -5.961]        71

# %%
df['Volume'].value_counts(bins = 50).to_frame().nlargest(5,'Volume')
# Out:
#                                       Volume
# (-322425427.47999996, 7047302549.58]    1028
# (14066091099.16, 21084879648.74]         226
# (7047302549.58, 14066091099.16]          183
# (21084879648.74, 28103668198.32]         181
# (28103668198.32, 35122456747.9]          137

# %%
# Highlight column 'AdjC_pct' and put bar on 'Volume'
df.sample(3).style.applymap(above_zero, subset=['AdjC_pct'])\
.bar(subset = ['Volume'])\
.format({'Adj Close': "{:.2f}",'AdjC_pct': "{:.2f}",'AdjC_cum': "{:.2f}"})\
.highlight_max()
# Out:
# <style type="text/css">
# #T_b0f5c_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 1.2%, transparent 1.2%);
# }
# #T_b0f5c_row0_col3, #T_b0f5c_row1_col3 {
#   color: red;
# }
# #T_b0f5c_row1_col1 {
#   width: 10em;
#   height: 80%;
# }
# #T_b0f5c_row2_col0, #T_b0f5c_row2_col2 {
#   background-color: yellow;
# }
# #T_b0f5c_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#   background-color: yellow;
# }
# #T_b0f5c_row2_col3 {
#   color: green;
#   background-color: yellow;
# }
# </style>
# <table id="T_b0f5c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Adj Close</th>
#       <th class="col_heading level0 col1" >Volume</th>
#       <th class="col_heading level0 col2" >AdjC_cum</th>
#       <th class="col_heading level0 col3" >AdjC_pct</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0f5c_level0_row0" class="row_heading level0 row0" >2016-06-25 00:00:00</th>
#       <td id="T_b0f5c_row0_col0" class="data row0 col0" >665.12</td>
#       <td id="T_b0f5c_row0_col1" class="data row0 col1" >126656000</td>
#       <td id="T_b0f5c_row0_col2" class="data row0 col2" >234.55</td>
#       <td id="T_b0f5c_row0_col3" class="data row0 col3" >-0.03</td>
#     </tr>
#     <tr>
#       <th id="T_b0f5c_level0_row1" class="row_heading level0 row1" >2016-11-07 00:00:00</th>
#       <td id="T_b0f5c_row1_col0" class="data row1 col0" >703.13</td>
#       <td id="T_b0f5c_row1_col1" class="data row1 col1" >65047100</td>
#       <td id="T_b0f5c_row1_col2" class="data row1 col2" >272.56</td>
#       <td id="T_b0f5c_row1_col3" class="data row1 col3" >-1.18</td>
#     </tr>
#     <tr>
#       <th id="T_b0f5c_level0_row2" class="row_heading level0 row2" >2018-12-26 00:00:00</th>
#       <td id="T_b0f5c_row2_col0" class="data row2 col0" >3857.30</td>
#       <td id="T_b0f5c_row2_col1" class="data row2 col1" >5326547918</td>
#       <td id="T_b0f5c_row2_col2" class="data row2 col2" >3426.73</td>
#       <td id="T_b0f5c_row2_col3" class="data row2 col3" >1.10</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Find out when was the highest volume transaction
df.loc[df['Volume'].idxmax()]

# Find out when was the lowest volume transaction
df.loc[df['Volume'].idxmin()]

# Find out when was the highest AdjC_pct occur
df.loc[df['AdjC_pct'].idxmax()]

# Find out when was the lowest AdjC_pct occur
df.loc[df['AdjC_pct'].idxmin()]
# Out:
# Adj Close    4.97e+03
# Volume       5.40e+10
# AdjC_cum     4.54e+03
# AdjC_pct    -3.72e+01
# Name: 2020-03-12 00:00:00, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Key insight based on daily basis transaction (2,091 data):<br/>
# 1. Typical BTC price % change is between <font color='black'>-2.8% to 3.4%</font>.<br/>
#     2. Highest BTC price % change is <font color='black'>25.2%</font> occur on Dec 12th, 2017.<br/>
#     3. Lowest BTC price % change is <font color='black'>-37.2%</font> occur on Mar 12th, 2020.<br/>
# 4. Typical volume transaction spans from <font color='black'>-300 million USD to 7 billion USD</font>.<br/>
# 5. Highest volume transaction is <font color='black'>350 billion USD</font> occur on Feb 26th, 2021.<br/>
# 6. Lowest volume transaction is <font color='black'>28 million USD</font> occur on May 5th, 2016.<br/>
# </div>

# %%
# Create list of days category
dayscat = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Create list of months category
monthscat = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# %% [markdown]
# ### Check typical % change in monthly basis

# %%
# Groupby months name → find average → highlight on volume
df.groupby(df.index.month_name()).mean().reindex(monthscat).style.applymap(above_zero, subset=['AdjC_pct'])\
.format({'Adj Close': "{:.2f}",\
         'Volume': "{:.0f}",\
         'AdjC_pct': "{:.2f}",\
         'AdjC_cum': "{:.2f}"})\
.bar(subset = ['Volume'])
# Out:
# <style type="text/css">
# #T_6494d_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 73.4%, transparent 73.4%);
# }
# #T_6494d_row0_col3, #T_6494d_row1_col3, #T_6494d_row3_col3, #T_6494d_row4_col3, #T_6494d_row5_col3, #T_6494d_row6_col3, #T_6494d_row7_col3, #T_6494d_row9_col3, #T_6494d_row10_col3, #T_6494d_row11_col3 {
#   color: green;
# }
# #T_6494d_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
# }
# #T_6494d_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 68.2%, transparent 68.2%);
# }
# #T_6494d_row2_col3, #T_6494d_row8_col3 {
#   color: red;
# }
# #T_6494d_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 80.3%, transparent 80.3%);
# }
# #T_6494d_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 99.7%, transparent 99.7%);
# }
# #T_6494d_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 39.0%, transparent 39.0%);
# }
# #T_6494d_row6_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 15.1%, transparent 15.1%);
# }
# #T_6494d_row7_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 25.1%, transparent 25.1%);
# }
# #T_6494d_row8_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 33.3%, transparent 33.3%);
# }
# #T_6494d_row9_col1 {
#   width: 10em;
#   height: 80%;
# }
# #T_6494d_row10_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 29.9%, transparent 29.9%);
# }
# #T_6494d_row11_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 43.7%, transparent 43.7%);
# }
# </style>
# <table id="T_6494d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Adj Close</th>
#       <th class="col_heading level0 col1" >Volume</th>
#       <th class="col_heading level0 col2" >AdjC_cum</th>
#       <th class="col_heading level0 col3" >AdjC_pct</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6494d_level0_row0" class="row_heading level0 row0" >January</th>
#       <td id="T_6494d_row0_col0" class="data row0 col0" >10200.87</td>
#       <td id="T_6494d_row0_col1" class="data row0 col1" >19352123816</td>
#       <td id="T_6494d_row0_col2" class="data row0 col2" >9770.30</td>
#       <td id="T_6494d_row0_col3" class="data row0 col3" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_6494d_level0_row1" class="row_heading level0 row1" >February</th>
#       <td id="T_6494d_row1_col0" class="data row1 col0" >11685.35</td>
#       <td id="T_6494d_row1_col1" class="data row1 col1" >22738275797</td>
#       <td id="T_6494d_row1_col2" class="data row1 col2" >11254.78</td>
#       <td id="T_6494d_row1_col3" class="data row1 col3" >0.50</td>
#     </tr>
#     <tr>
#       <th id="T_6494d_level0_row2" class="row_heading level0 row2" >March</th>
#       <td id="T_6494d_row2_col0" class="data row2 col0" >12738.59</td>
#       <td id="T_6494d_row2_col1" class="data row2 col1" >18691054476</td>
#       <td id="T_6494d_row2_col2" class="data row2 col2" >12308.02</td>
#       <td id="T_6494d_row2_col3" class="data row2 col3" >-0.15</td>
#     </tr>
#     <tr>
#       <th id="T_6494d_level0_row3" class="row_heading level0 row3" >April</th>
#       <td id="T_6494d_row3_col0" class="data row3 col0" >13248.22</td>
#       <td id="T_6494d_row3_col1" class="data row3 col1" >20232284940</td>
#       <td id="T_6494d_row3_col2" class="data row3 col2" >12817.65</td>
#       <td id="T_6494d_row3_col3" class="data row3 col3" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_6494d_level0_row4" class="row_heading level0 row4" >May</th>
#       <td id="T_6494d_row4_col0" class="data row4 col0" >12304.08</td>
#       <td id="T_6494d_row4_col1" class="data row4 col1" >22694771238</td>
#       <td id="T_6494d_row4_col2" class="data row4 col2" >11873.51</td>
#       <td id="T_6494d_row4_col3" class="data row4 col3" >0.42</td>
#     </tr>
#     <tr>
#       <th id="T_6494d_level0_row5" class="row_heading level0 row5" >June</th>
#       <td id="T_6494d_row5_col0" class="data row5 col0" >10803.81</td>
#       <td id="T_6494d_row5_col1" class="data row5 col1" >14976989882</td>
#       <td id="T_6494d_row5_col2" class="data row5 col2" >10373.24</td>
#       <td id="T_6494d_row5_col3" class="data row5 col3" >0.26</td>
#     </tr>
#     <tr>
#       <th id="T_6494d_level0_row6" class="row_heading level0 row6" >July</th>
#       <td id="T_6494d_row6_col0" class="data row6 col0" >10838.56</td>
#       <td id="T_6494d_row6_col1" class="data row6 col1" >11929296398</td>
#       <td id="T_6494d_row6_col2" class="data row6 col2" >10407.99</td>
#       <td id="T_6494d_row6_col3" class="data row6 col3" >0.39</td>
#     </tr>
#     <tr>
#       <th id="T_6494d_level0_row7" class="row_heading level0 row7" >August</th>
#       <td id="T_6494d_row7_col0" class="data row7 col0" >13194.23</td>
#       <td id="T_6494d_row7_col1" class="data row7 col1" >13201952984</td>
#       <td id="T_6494d_row7_col2" class="data row7 col2" >12763.66</td>
#       <td id="T_6494d_row7_col3" class="data row7 col3" >0.27</td>
#     </tr>
#     <tr>
#       <th id="T_6494d_level0_row8" class="row_heading level0 row8" >September</th>
#       <td id="T_6494d_row8_col0" class="data row8 col0" >11932.82</td>
#       <td id="T_6494d_row8_col1" class="data row8 col1" >14245875997</td>
#       <td id="T_6494d_row8_col2" class="data row8 col2" >11502.25</td>
#       <td id="T_6494d_row8_col3" class="data row8 col3" >-0.17</td>
#     </tr>
#     <tr>
#       <th id="T_6494d_level0_row9" class="row_heading level0 row9" >October</th>
#       <td id="T_6494d_row9_col0" class="data row9 col0" >6463.56</td>
#       <td id="T_6494d_row9_col1" class="data row9 col1" >10011567234</td>
#       <td id="T_6494d_row9_col2" class="data row9 col2" >6032.99</td>
#       <td id="T_6494d_row9_col3" class="data row9 col3" >0.59</td>
#     </tr>
#     <tr>
#       <th id="T_6494d_level0_row10" class="row_heading level0 row10" >November</th>
#       <td id="T_6494d_row10_col0" class="data row10 col0" >7792.61</td>
#       <td id="T_6494d_row10_col1" class="data row10 col1" >13811964965</td>
#       <td id="T_6494d_row10_col2" class="data row10 col2" >7362.04</td>
#       <td id="T_6494d_row10_col3" class="data row10 col3" >0.22</td>
#     </tr>
#     <tr>
#       <th id="T_6494d_level0_row11" class="row_heading level0 row11" >December</th>
#       <td id="T_6494d_row11_col0" class="data row11 col0" >9761.20</td>
#       <td id="T_6494d_row11_col1" class="data row11 col1" >15569334269</td>
#       <td id="T_6494d_row11_col2" class="data row11 col2" >9330.63</td>
#       <td id="T_6494d_row11_col3" class="data row11 col3" >0.66</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Set pivot table based segregate based on year and month name, then calculate the mean aggregate
df2 = df.pivot_table(index=df.index.year,
                     columns = df.index.month_name(),
                     fill_value = 0,
                     aggfunc = {'AdjC_pct':'mean'})

# Remove the first multi index column 
df2.columns = df2.columns.droplevel(0)

# Re-index based on monthscat
df2 = df2.reindex(columns=monthscat)

# Apply style
df2.style.applymap(above_zero).background_gradient(cmap='RdYlGn_r')
# Out:
# <style type="text/css">
# #T_d52d7_row0_col0 {
#   color: red;
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_d52d7_row0_col1 {
#   color: red;
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_d52d7_row0_col2 {
#   color: red;
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_d52d7_row0_col3 {
#   color: red;
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_d52d7_row0_col4 {
#   color: red;
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_d52d7_row0_col5, #T_d52d7_row5_col2 {
#   color: red;
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_d52d7_row0_col6 {
#   color: red;
#   background-color: #78c565;
#   color: #000000;
# }
# #T_d52d7_row0_col7 {
#   color: red;
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_d52d7_row0_col8 {
#   color: red;
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_d52d7_row0_col9, #T_d52d7_row4_col7, #T_d52d7_row6_col9 {
#   color: red;
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_d52d7_row0_col10, #T_d52d7_row6_col10 {
#   color: red;
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_d52d7_row0_col11, #T_d52d7_row6_col11 {
#   color: red;
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_d52d7_row1_col0, #T_d52d7_row4_col10 {
#   color: red;
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_d52d7_row1_col1 {
#   color: green;
#   background-color: #fee695;
#   color: #000000;
# }
# #T_d52d7_row1_col2 {
#   color: red;
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_d52d7_row1_col3 {
#   color: green;
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_d52d7_row1_col4 {
#   color: green;
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_d52d7_row1_col5 {
#   color: green;
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_d52d7_row1_col6, #T_d52d7_row3_col0, #T_d52d7_row3_col2, #T_d52d7_row3_col5, #T_d52d7_row3_col7, #T_d52d7_row3_col9, #T_d52d7_row3_col10, #T_d52d7_row3_col11, #T_d52d7_row4_col8, #T_d52d7_row4_col11, #T_d52d7_row5_col1, #T_d52d7_row6_col3, #T_d52d7_row6_col4 {
#   color: red;
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_d52d7_row1_col7 {
#   color: red;
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_d52d7_row1_col8, #T_d52d7_row2_col4, #T_d52d7_row2_col7, #T_d52d7_row2_col9, #T_d52d7_row2_col10, #T_d52d7_row2_col11, #T_d52d7_row4_col5, #T_d52d7_row5_col0, #T_d52d7_row5_col3, #T_d52d7_row5_col6, #T_d52d7_row6_col1, #T_d52d7_row6_col2 {
#   color: green;
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_d52d7_row1_col9 {
#   color: green;
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_d52d7_row1_col10 {
#   color: green;
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_d52d7_row1_col11 {
#   color: green;
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_d52d7_row2_col0 {
#   color: green;
#   background-color: #fee797;
#   color: #000000;
# }
# #T_d52d7_row2_col1 {
#   color: green;
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_d52d7_row2_col2 {
#   color: red;
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_d52d7_row2_col3 {
#   color: green;
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_d52d7_row2_col5 {
#   color: green;
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_d52d7_row2_col6, #T_d52d7_row4_col4, #T_d52d7_row5_col11 {
#   color: green;
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_d52d7_row2_col8 {
#   color: red;
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_d52d7_row3_col1 {
#   color: green;
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_d52d7_row3_col3 {
#   color: green;
#   background-color: #bb1526;
#   color: #f1f1f1;
# }
# #T_d52d7_row3_col4 {
#   color: red;
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_d52d7_row3_col6 {
#   color: green;
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_d52d7_row3_col8 {
#   color: red;
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_d52d7_row4_col0 {
#   color: red;
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_d52d7_row4_col1 {
#   color: green;
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_d52d7_row4_col2 {
#   color: green;
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_d52d7_row4_col3, #T_d52d7_row5_col10 {
#   color: green;
#   background-color: #de402e;
#   color: #f1f1f1;
# }
# #T_d52d7_row4_col6 {
#   color: red;
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_d52d7_row4_col9 {
#   color: green;
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_d52d7_row5_col4 {
#   color: green;
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_d52d7_row5_col5 {
#   color: red;
#   background-color: #93d168;
#   color: #000000;
# }
# #T_d52d7_row5_col7 {
#   color: green;
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_d52d7_row5_col8 {
#   color: red;
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_d52d7_row5_col9 {
#   color: green;
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_d52d7_row6_col0 {
#   color: green;
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_d52d7_row6_col5 {
#   color: red;
#   background-color: #96d268;
#   color: #000000;
# }
# #T_d52d7_row6_col6 {
#   color: green;
#   background-color: #dd3d2d;
#   color: #f1f1f1;
# }
# #T_d52d7_row6_col7 {
#   color: green;
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_d52d7_row6_col8 {
#   color: red;
#   background-color: #70c164;
#   color: #000000;
# }
# </style>
# <table id="T_d52d7_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="col_heading level0 col0" >January</th>
#       <th class="col_heading level0 col1" >February</th>
#       <th class="col_heading level0 col2" >March</th>
#       <th class="col_heading level0 col3" >April</th>
#       <th class="col_heading level0 col4" >May</th>
#       <th class="col_heading level0 col5" >June</th>
#       <th class="col_heading level0 col6" >July</th>
#       <th class="col_heading level0 col7" >August</th>
#       <th class="col_heading level0 col8" >September</th>
#       <th class="col_heading level0 col9" >October</th>
#       <th class="col_heading level0 col10" >November</th>
#       <th class="col_heading level0 col11" >December</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d52d7_level0_row0" class="row_heading level0 row0" >2015</th>
#       <td id="T_d52d7_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_d52d7_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_d52d7_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_d52d7_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_d52d7_row0_col4" class="data row0 col4" >0.00</td>
#       <td id="T_d52d7_row0_col5" class="data row0 col5" >0.00</td>
#       <td id="T_d52d7_row0_col6" class="data row0 col6" >0.00</td>
#       <td id="T_d52d7_row0_col7" class="data row0 col7" >0.00</td>
#       <td id="T_d52d7_row0_col8" class="data row0 col8" >0.00</td>
#       <td id="T_d52d7_row0_col9" class="data row0 col9" >0.00</td>
#       <td id="T_d52d7_row0_col10" class="data row0 col10" >0.00</td>
#       <td id="T_d52d7_row0_col11" class="data row0 col11" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_d52d7_level0_row1" class="row_heading level0 row1" >2016</th>
#       <td id="T_d52d7_row1_col0" class="data row1 col0" >-0.41</td>
#       <td id="T_d52d7_row1_col1" class="data row1 col1" >0.61</td>
#       <td id="T_d52d7_row1_col2" class="data row1 col2" >-0.15</td>
#       <td id="T_d52d7_row1_col3" class="data row1 col3" >0.25</td>
#       <td id="T_d52d7_row1_col4" class="data row1 col4" >0.58</td>
#       <td id="T_d52d7_row1_col5" class="data row1 col5" >0.90</td>
#       <td id="T_d52d7_row1_col6" class="data row1 col6" >-0.21</td>
#       <td id="T_d52d7_row1_col7" class="data row1 col7" >-0.24</td>

# %%
# Apply style in transpose to reconfirm the pattern
df2.T.style.applymap(above_zero).background_gradient(cmap='RdYlGn_r')
# Out:
# <style type="text/css">
# #T_7746d_row0_col0, #T_7746d_row0_col1, #T_7746d_row1_col0, #T_7746d_row2_col0, #T_7746d_row2_col2, #T_7746d_row2_col5, #T_7746d_row3_col0, #T_7746d_row4_col0, #T_7746d_row4_col6, #T_7746d_row5_col0, #T_7746d_row6_col0, #T_7746d_row7_col0, #T_7746d_row8_col0, #T_7746d_row9_col0, #T_7746d_row10_col0, #T_7746d_row10_col3, #T_7746d_row10_col4, #T_7746d_row11_col0 {
#   color: red;
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_7746d_row0_col2 {
#   color: green;
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# #T_7746d_row0_col3 {
#   color: red;
#   background-color: #75c465;
#   color: #000000;
# }
# #T_7746d_row0_col4 {
#   color: red;
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# #T_7746d_row0_col5 {
#   color: green;
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_7746d_row0_col6 {
#   color: green;
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_7746d_row1_col1, #T_7746d_row9_col2 {
#   color: green;
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_7746d_row1_col2 {
#   color: green;
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_7746d_row1_col3 {
#   color: green;
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_7746d_row1_col4, #T_7746d_row8_col1 {
#   color: green;
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_7746d_row1_col5 {
#   color: red;
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_7746d_row1_col6, #T_7746d_row3_col3, #T_7746d_row4_col2, #T_7746d_row4_col4, #T_7746d_row5_col1, #T_7746d_row11_col5 {
#   color: green;
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_7746d_row2_col1 {
#   color: red;
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_7746d_row2_col3 {
#   color: red;
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_7746d_row2_col4 {
#   color: green;
#   background-color: #c9e881;
#   color: #000000;
# }
# #T_7746d_row2_col6 {
#   color: green;
#   background-color: #de402e;
#   color: #f1f1f1;
# }
# #T_7746d_row3_col1 {
#   color: green;
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_7746d_row3_col2 {
#   color: green;
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_7746d_row3_col4 {
#   color: green;
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_7746d_row3_col5 {
#   color: green;
#   background-color: #e0422f;
#   color: #f1f1f1;
# }
# #T_7746d_row3_col6 {
#   color: red;
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_7746d_row4_col1 {
#   color: green;
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_7746d_row4_col3 {
#   color: red;
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_7746d_row4_col5 {
#   color: green;
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_7746d_row5_col2 {
#   color: green;
#   background-color: #96d268;
#   color: #000000;
# }
# #T_7746d_row5_col3 {
#   color: red;
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_7746d_row5_col4, #T_7746d_row7_col6 {
#   color: green;
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_7746d_row5_col5 {
#   color: red;
#   background-color: #70c164;
#   color: #000000;
# }
# #T_7746d_row5_col6 {
#   color: red;
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_7746d_row6_col1 {
#   color: red;
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_7746d_row6_col2 {
#   color: green;
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_7746d_row6_col3 {
#   color: green;
#   background-color: #e44c34;
#   color: #f1f1f1;
# }
# #T_7746d_row6_col4, #T_7746d_row7_col4 {
#   color: red;
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_7746d_row6_col5 {
#   color: green;
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_7746d_row6_col6 {
#   color: green;
#   background-color: #f99355;
#   color: #000000;
# }
# #T_7746d_row7_col1 {
#   color: red;
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_7746d_row7_col2 {
#   color: green;
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_7746d_row7_col3 {
#   color: red;
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_7746d_row7_col5 {
#   color: green;
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_7746d_row8_col2 {
#   color: red;
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_7746d_row8_col3, #T_7746d_row9_col6, #T_7746d_row10_col6, #T_7746d_row11_col6 {
#   color: red;
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_7746d_row8_col4 {
#   color: red;
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_7746d_row8_col5 {
#   color: red;
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_7746d_row8_col6 {
#   color: red;
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_7746d_row9_col1 {
#   color: green;
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_7746d_row9_col3 {
#   color: red;
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_7746d_row9_col4 {
#   color: green;
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_7746d_row9_col5 {
#   color: green;
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_7746d_row10_col1 {
#   color: green;
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_7746d_row10_col2 {
#   color: green;
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_7746d_row10_col5, #T_7746d_row11_col1 {
#   color: green;
#   background-color: #b91326;
#   color: #f1f1f1;
# }
# #T_7746d_row11_col2 {
#   color: green;
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_7746d_row11_col3 {
#   color: red;
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_7746d_row11_col4 {
#   color: red;
#   background-color: #6ec064;
#   color: #000000;
# }
# </style>
# <table id="T_7746d_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="col_heading level0 col0" >2015</th>
#       <th class="col_heading level0 col1" >2016</th>
#       <th class="col_heading level0 col2" >2017</th>
#       <th class="col_heading level0 col3" >2018</th>
#       <th class="col_heading level0 col4" >2019</th>
#       <th class="col_heading level0 col5" >2020</th>
#       <th class="col_heading level0 col6" >2021</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7746d_level0_row0" class="row_heading level0 row0" >January</th>
#       <td id="T_7746d_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_7746d_row0_col1" class="data row0 col1" >-0.41</td>
#       <td id="T_7746d_row0_col2" class="data row0 col2" >0.15</td>
#       <td id="T_7746d_row0_col3" class="data row0 col3" >-0.84</td>
#       <td id="T_7746d_row0_col4" class="data row0 col4" >-0.22</td>
#       <td id="T_7746d_row0_col5" class="data row0 col5" >0.89</td>
#       <td id="T_7746d_row0_col6" class="data row0 col6" >0.58</td>
#     </tr>
#     <tr>
#       <th id="T_7746d_level0_row1" class="row_heading level0 row1" >February</th>
#       <td id="T_7746d_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_7746d_row1_col1" class="data row1 col1" >0.61</td>
#       <td id="T_7746d_row1_col2" class="data row1 col2" >0.72</td>
#       <td id="T_7746d_row1_col3" class="data row1 col3" >0.31</td>
#       <td id="T_7746d_row1_col4" class="data row1 col4" >0.42</td>
#       <td id="T_7746d_row1_col5" class="data row1 col5" >-0.26</td>
#       <td id="T_7746d_row1_col6" class="data row1 col6" >1.24</td>
#     </tr>
#     <tr>
#       <th id="T_7746d_level0_row2" class="row_heading level0 row2" >March</th>
#       <td id="T_7746d_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_7746d_row2_col1" class="data row2 col1" >-0.15</td>
#       <td id="T_7746d_row2_col2" class="data row2 col2" >-0.19</td>
#       <td id="T_7746d_row2_col3" class="data row2 col3" >-1.18</td>
#       <td id="T_7746d_row2_col4" class="data row2 col4" >0.21</td>
#       <td id="T_7746d_row2_col5" class="data row2 col5" >-0.48</td>
#       <td id="T_7746d_row2_col6" class="data row2 col6" >0.93</td>
#     </tr>
#     <tr>
#       <th id="T_7746d_level0_row3" class="row_heading level0 row3" >April</th>
#       <td id="T_7746d_row3_col0" class="data row3 col0" >0.00</td>
#       <td id="T_7746d_row3_col1" cla

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Key insight:<br/>
# 1. <font color='green'>March and September</font> is the month with lowest % price change.<br/>
# 2. <font color='red'>April and July</font> is the month with highest % price change.<br/>
# 3. BTC volume transaction typically active at the first half of the year.<br/>
# 4. No common pattern seen from BTC transaction since 2016 up to 2021.<br/>
# 5. <font color='red'>BTC price % pattern start change since 2020 onward</font>.<br/>
# </div>

# %% [markdown]
# ### Check typical % change in daily basis

# %%
# Groupby days name → find average → highlight on volume → set precision
df.groupby(df.index.day_name()).mean().reindex(dayscat).style\
.bar(subset = ['Volume'])\
.format({'Adj Close': "{:.2f}",\
         'Volume': "{:.0f}",\
         'AdjC_pct': "{:.2f}",\
         'AdjC_cum': "{:.2f}"})
# Out:
# <style type="text/css">
# #T_6f04c_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 68.1%, transparent 68.1%);
# }
# #T_6f04c_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 67.1%, transparent 67.1%);
# }
# #T_6f04c_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 84.0%, transparent 84.0%);
# }
# #T_6f04c_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 85.7%, transparent 85.7%);
# }
# #T_6f04c_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
# }
# #T_6f04c_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 1.3%, transparent 1.3%);
# }
# #T_6f04c_row6_col1 {
#   width: 10em;
#   height: 80%;
# }
# </style>
# <table id="T_6f04c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Adj Close</th>
#       <th class="col_heading level0 col1" >Volume</th>
#       <th class="col_heading level0 col2" >AdjC_cum</th>
#       <th class="col_heading level0 col3" >AdjC_pct</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f04c_level0_row0" class="row_heading level0 row0" >Monday</th>
#       <td id="T_6f04c_row0_col0" class="data row0 col0" >11023.44</td>
#       <td id="T_6f04c_row0_col1" class="data row0 col1" >16879343629</td>
#       <td id="T_6f04c_row0_col2" class="data row0 col2" >10592.87</td>
#       <td id="T_6f04c_row0_col3" class="data row0 col3" >0.57</td>
#     </tr>
#     <tr>
#       <th id="T_6f04c_level0_row1" class="row_heading level0 row1" >Tuesday</th>
#       <td id="T_6f04c_row1_col0" class="data row1 col0" >11006.03</td>
#       <td id="T_6f04c_row1_col1" class="data row1 col1" >16847867596</td>
#       <td id="T_6f04c_row1_col2" class="data row1 col2" >10575.46</td>
#       <td id="T_6f04c_row1_col3" class="data row1 col3" >0.15</td>
#     </tr>
#     <tr>
#       <th id="T_6f04c_level0_row2" class="row_heading level0 row2" >Wednesday</th>
#       <td id="T_6f04c_row2_col0" class="data row2 col0" >11064.96</td>
#       <td id="T_6f04c_row2_col1" class="data row2 col1" >17361362502</td>
#       <td id="T_6f04c_row2_col2" class="data row2 col2" >10634.39</td>
#       <td id="T_6f04c_row2_col3" class="data row2 col3" >0.42</td>
#     </tr>
#     <tr>
#       <th id="T_6f04c_level0_row3" class="row_heading level0 row3" >Thursday</th>
#       <td id="T_6f04c_row3_col0" class="data row3 col0" >11028.69</td>
#       <td id="T_6f04c_row3_col1" class="data row3 col1" >17411253361</td>
#       <td id="T_6f04c_row3_col2" class="data row3 col2" >10598.12</td>
#       <td id="T_6f04c_row3_col3" class="data row3 col3" >0.15</td>
#     </tr>
#     <tr>
#       <th id="T_6f04c_level0_row4" class="row_heading level0 row4" >Friday</th>
#       <td id="T_6f04c_row4_col0" class="data row4 col0" >11106.93</td>
#       <td id="T_6f04c_row4_col1" class="data row4 col1" >17844854425</td>
#       <td id="T_6f04c_row4_col2" class="data row4 col2" >10676.36</td>
#       <td id="T_6f04c_row4_col3" class="data row4 col3" >0.34</td>
#     </tr>
#     <tr>
#       <th id="T_6f04c_level0_row5" class="row_heading level0 row5" >Saturday</th>
#       <td id="T_6f04c_row5_col0" class="data row5 col0" >11021.08</td>
#       <td id="T_6f04c_row5_col1" class="data row5 col1" >14856512865</td>
#       <td id="T_6f04c_row5_col2" class="data row5 col2" >10590.51</td>
#       <td id="T_6f04c_row5_col3" class="data row5 col3" >0.45</td>
#     </tr>
#     <tr>
#       <th id="T_6f04c_level0_row6" class="row_heading level0 row6" >Sunday</th>
#       <td id="T_6f04c_row6_col0" class="data row6 col0" >11008.21</td>
#       <td id="T_6f04c_row6_col1" class="data row6 col1" >14818629742</td>
#       <td id="T_6f04c_row6_col2" class="data row6 col2" >10577.64</td>
#       <td id="T_6f04c_row6_col3" class="data row6 col3" >0.02</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Set pivot table based segregate based on year and day name, then calculate the mean aggregate
df3 = df.pivot_table(index=df.index.year,
                     columns = df.index.day_name(),
                     fill_value = 0,
                     aggfunc = {'AdjC_pct':'mean'})

# Remove the first multi index column 
df3.columns = df3.columns.droplevel(0)

# Re-index based on dayscat
df3 = df3.reindex(columns=dayscat)

# Fill NaN value with zero
df3.fillna(value = 0, inplace = True)

# Apply style
df3.style.applymap(above_zero).background_gradient(cmap='RdYlGn_r')
# Out:
# <style type="text/css">
# #T_39ac2_row0_col0 {
#   color: red;
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_39ac2_row0_col1 {
#   color: red;
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_39ac2_row0_col2 {
#   color: red;
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_39ac2_row0_col3 {
#   color: red;
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_39ac2_row0_col4 {
#   color: red;
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_39ac2_row0_col5, #T_39ac2_row2_col4, #T_39ac2_row3_col0, #T_39ac2_row3_col1, #T_39ac2_row3_col2, #T_39ac2_row3_col6, #T_39ac2_row4_col3 {
#   color: red;
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_39ac2_row0_col6 {
#   color: red;
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_39ac2_row1_col0 {
#   color: green;
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_39ac2_row1_col1 {
#   color: red;
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_39ac2_row1_col2 {
#   color: green;
#   background-color: #fec877;
#   color: #000000;
# }
# #T_39ac2_row1_col3, #T_39ac2_row6_col6 {
#   color: green;
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_39ac2_row1_col4 {
#   color: green;
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_39ac2_row1_col5, #T_39ac2_row2_col0, #T_39ac2_row2_col1, #T_39ac2_row2_col3, #T_39ac2_row2_col6, #T_39ac2_row4_col4, #T_39ac2_row6_col2 {
#   color: green;
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_39ac2_row1_col6 {
#   color: green;
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_39ac2_row2_col2 {
#   color: green;
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_39ac2_row2_col5 {
#   color: green;
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_39ac2_row3_col3 {
#   color: red;
#   background-color: #9bd469;
#   color: #000000;
# }
# #T_39ac2_row3_col4 {
#   color: green;
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_39ac2_row3_col5 {
#   color: green;
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_39ac2_row4_col0 {
#   color: green;
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_39ac2_row4_col1 {
#   color: red;
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_39ac2_row4_col2 {
#   color: green;
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_39ac2_row4_col5 {
#   color: green;
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_39ac2_row4_col6 {
#   color: green;
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_39ac2_row5_col0 {
#   color: green;
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_39ac2_row5_col1 {
#   color: green;
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_39ac2_row5_col2 {
#   color: green;
#   background-color: #b91326;
#   color: #f1f1f1;
# }
# #T_39ac2_row5_col3 {
#   color: green;
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_39ac2_row5_col4 {
#   color: green;
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_39ac2_row5_col5 {
#   color: green;
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_39ac2_row5_col6 {
#   color: red;
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_39ac2_row6_col0 {
#   color: red;
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_39ac2_row6_col1 {
#   color: red;
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_39ac2_row6_col3 {
#   color: green;
#   background-color: #dff293;
#   color: #000000;
# }
# #T_39ac2_row6_col4 {
#   color: green;
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_39ac2_row6_col5 {
#   color: green;
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_39ac2_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="col_heading level0 col0" >Monday</th>
#       <th class="col_heading level0 col1" >Tuesday</th>
#       <th class="col_heading level0 col2" >Wednesday</th>
#       <th class="col_heading level0 col3" >Thursday</th>
#       <th class="col_heading level0 col4" >Friday</th>
#       <th class="col_heading level0 col5" >Saturday</th>
#       <th class="col_heading level0 col6" >Sunday</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39ac2_level0_row0" class="row_heading level0 row0" >2015</th>
#       <td id="T_39ac2_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_39ac2_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_39ac2_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_39ac2_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_39ac2_row0_col4" class="data row0 col4" >0.00</td>
#       <td id="T_39ac2_row0_col5" class="data row0 col5" >0.00</td>
#       <td id="T_39ac2_row0_col6" class="data row0 col6" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_39ac2_level0_row1" class="row_heading level0 row1" >2016</th>
#       <td id="T_39ac2_row1_col0" class="data row1 col0" >0.20</td>
#       <td id="T_39ac2_row1_col1" class="data row1 col1" >-0.21</td>
#       <td id="T_39ac2_row1_col2" class="data row1 col2" >0.36</td>
#       <td id="T_39ac2_row1_col3" class="data row1 col3" >0.42</td>
#       <td id="T_39ac2_row1_col4" class="data row1 col4" >0.29</td>
#       <td id="T_39ac2_row1_col5" class="data row1 col5" >0.64</td>
#       <td id="T_39ac2_row1_col6" class="data row1 col6" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_39ac2_level0_row2" class="row_heading level0 row2" >2017</th>
#       <td id="T_39ac2_row2_col0" class="data row2 col0" >2.10</td>
#       <td id="T_39ac2_row2_col1" class="data row2 col1" >1.12</td>
#       <td id="T_39ac2_row2_col2" class="data row2 col2" >0.65</td>
#       <td id="T_39ac2_row2_col3" class="data row2 col3" >1.28</td>
#       <td id="T_39ac2_row2_col4" class="data row2 col4" >-0.29</td>
#       <td id="T_39ac2_row2_col5" class="data row2 col5" >0.64</td>
#       <td id="T_39ac2_row2_col6" class="data row2 col6" >0.54</td>
#     </tr>
#     <tr>
#       <th id="T_39ac2_level0_row3" class="row_heading level0 row3" >2018</th>
#       <td id="T_39ac2_row3_col0" class="data row3 col0" >-0.66</td>
#       <td id="T_39ac2_row3_col1" class="data row3 col1" >-0.34</td>
#       <td id="T_39ac2_row3_col2" class="data row3 col2" >-0.81</td>
#       <td id="T_39ac2_row3_col3" class="data row3 col3" >-0.22</td>
#       <td id="T_39ac2_row3_col4" class="data row3 col4" >0.00</td>
#       <td id="T_39ac2_row3_col5" class="data row3 col5" >0.48</td>
#       <td id="T_39ac2_row3_col6" class="data row3 col6" >-0.36</td>
#     </tr>
#     <tr>
#       <th id="T_39ac2_level0_row4" class="row_heading level0 row4" >2019</th>
#       <td id="T_39ac2_row4_col0" class="data row4 col0" >0.58</td>
#       <td id="T_39ac2_row4_col1" class="data row4 col1" >-0.23</td>
#       <td id="T_39ac2_row4_col2" class="data row4 col2" >0.56</td>
#       <td id="T_39ac2_row4_col3" class="data row4 col3" >-0.81</td>
#       <td id="T_39ac2_row4_col4" class="data row4 col4" >1.08</td>
#       <td id="T_39ac2_row4_col5" class="data row4 col5" >0.46</td>
#       <td id="T_39ac2_row4_col6" class="data row4 col6" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_39ac2_level0_row5" class="row_heading level0 row5" >2020</th>
#       <td id="T_39ac2_row5_col0" class="data row5 col0" >1.21</td>
#       <td id="T_39ac2_row5_col1" class="data row5 col1" >0.68</td>
#       <td id="T_39ac2_row5_col2" class="data row5 col2" >0.92</td>
#       <td id="T_39ac2_row5_col3" class="data row5 col3" >0.17</td>
#       <td id="T_39ac2_row5_col4" class="data row5 col4" >0.30</td>
#       <td id="T_39ac2_row5_col5" class="data row5 col5" >0.30</td>
#       <td id="T_39ac2_row5_col6" class="data row5 col6" >-0.33</td>
#     </tr>
#     <tr>
#       <th id="T_39ac2_level0_row6" class="row_heading level0 row6" >2021</th>
#       <td id="T_39ac2_row6_col0" class="data row6 col0" >-0.16</td>
#       <td id="T_39ac2_row6_col1" class="data row6 col1" >-0.20</td>
#       <td id="T_39ac2_row6_col2" class="data row6 col2" >1.00</td>
#       <td id="T_39ac2_row6_col3" class="data row6 col3" >0.06</td>

# %%
# Apply style in transpose to reconfirm the pattern
df3.T.style.applymap(above_zero).background_gradient(cmap='RdYlGn_r')
# Out:
# <style type="text/css">
# #T_4d072_row0_col0, #T_4d072_row1_col0, #T_4d072_row1_col1, #T_4d072_row1_col6, #T_4d072_row2_col0, #T_4d072_row2_col3, #T_4d072_row3_col0, #T_4d072_row3_col4, #T_4d072_row4_col0, #T_4d072_row4_col2, #T_4d072_row5_col0, #T_4d072_row6_col0, #T_4d072_row6_col5 {
#   color: red;
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_4d072_row0_col1 {
#   color: green;
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_4d072_row0_col2, #T_4d072_row0_col5, #T_4d072_row2_col6, #T_4d072_row4_col4, #T_4d072_row5_col1, #T_4d072_row5_col3 {
#   color: green;
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_4d072_row0_col3 {
#   color: red;
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_4d072_row0_col4 {
#   color: green;
#   background-color: #f99355;
#   color: #000000;
# }
# #T_4d072_row0_col6 {
#   color: red;
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_4d072_row1_col2 {
#   color: green;
#   background-color: #fee491;
#   color: #000000;
# }
# #T_4d072_row1_col3 {
#   color: red;
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_4d072_row1_col4 {
#   color: red;
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_4d072_row1_col5, #T_4d072_row3_col2 {
#   color: green;
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_4d072_row2_col1 {
#   color: green;
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_4d072_row2_col2 {
#   color: green;
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_4d072_row2_col4 {
#   color: green;
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_4d072_row2_col5 {
#   color: green;
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_4d072_row3_col1 {
#   color: green;
#   background-color: #f99153;
#   color: #000000;
# }
# #T_4d072_row3_col3 {
#   color: red;
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_4d072_row3_col5 {
#   color: green;
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_4d072_row3_col6 {
#   color: green;
#   background-color: #73c264;
#   color: #000000;
# }
# #T_4d072_row4_col1 {
#   color: green;
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_4d072_row4_col3 {
#   color: green;
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_4d072_row4_col5, #T_4d072_row5_col5 {
#   color: green;
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_4d072_row4_col6 {
#   color: green;
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_4d072_row5_col2 {
#   color: green;
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_4d072_row5_col4 {
#   color: green;
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_4d072_row5_col6 {
#   color: green;
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_4d072_row6_col1 {
#   color: green;
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_4d072_row6_col2 {
#   color: green;
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_4d072_row6_col3 {
#   color: red;
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_4d072_row6_col4 {
#   color: green;
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_4d072_row6_col6 {
#   color: green;
#   background-color: #addc6f;
#   color: #000000;
# }
# </style>
# <table id="T_4d072_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="col_heading level0 col0" >2015</th>
#       <th class="col_heading level0 col1" >2016</th>
#       <th class="col_heading level0 col2" >2017</th>
#       <th class="col_heading level0 col3" >2018</th>
#       <th class="col_heading level0 col4" >2019</th>
#       <th class="col_heading level0 col5" >2020</th>
#       <th class="col_heading level0 col6" >2021</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d072_level0_row0" class="row_heading level0 row0" >Monday</th>
#       <td id="T_4d072_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_4d072_row0_col1" class="data row0 col1" >0.20</td>
#       <td id="T_4d072_row0_col2" class="data row0 col2" >2.10</td>
#       <td id="T_4d072_row0_col3" class="data row0 col3" >-0.66</td>
#       <td id="T_4d072_row0_col4" class="data row0 col4" >0.58</td>
#       <td id="T_4d072_row0_col5" class="data row0 col5" >1.21</td>
#       <td id="T_4d072_row0_col6" class="data row0 col6" >-0.16</td>
#     </tr>
#     <tr>
#       <th id="T_4d072_level0_row1" class="row_heading level0 row1" >Tuesday</th>
#       <td id="T_4d072_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_4d072_row1_col1" class="data row1 col1" >-0.21</td>
#       <td id="T_4d072_row1_col2" class="data row1 col2" >1.12</td>
#       <td id="T_4d072_row1_col3" class="data row1 col3" >-0.34</td>
#       <td id="T_4d072_row1_col4" class="data row1 col4" >-0.23</td>
#       <td id="T_4d072_row1_col5" class="data row1 col5" >0.68</td>
#       <td id="T_4d072_row1_col6" class="data row1 col6" >-0.20</td>
#     </tr>
#     <tr>
#       <th id="T_4d072_level0_row2" class="row_heading level0 row2" >Wednesday</th>
#       <td id="T_4d072_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_4d072_row2_col1" class="data row2 col1" >0.36</td>
#       <td id="T_4d072_row2_col2" class="data row2 col2" >0.65</td>
#       <td id="T_4d072_row2_col3" class="data row2 col3" >-0.81</td>
#       <td id="T_4d072_row2_col4" class="data row2 col4" >0.56</td>
#       <td id="T_4d072_row2_col5" class="data row2 col5" >0.92</td>
#       <td id="T_4d072_row2_col6" class="data row2 col6" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_4d072_level0_row3" class="row_heading level0 row3" >Thursday</th>
#       <td id="T_4d072_row3_col0" class="data row3 col0" >0.00</td>
#       <td id="T_4d072_row3_col1" class="data row3 col1" >0.42</td>
#       <td id="T_4d072_row3_col2" class="data row3 col2" >1.28</td>
#       <td id="T_4d072_row3_col3" class="data row3 col3" >-0.22</td>
#       <td id="T_4d072_row3_col4" class="data row3 col4" >-0.81</td>
#       <td id="T_4d072_row3_col5" class="data row3 col5" >0.17</td>
#       <td id="T_4d072_row3_col6" class="data row3 col6" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_4d072_level0_row4" class="row_heading level0 row4" >Friday</th>
#       <td id="T_4d072_row4_col0" class="data row4 col0" >0.00</td>
#       <td id="T_4d072_row4_col1" class="data row4 col1" >0.29</td>
#       <td id="T_4d072_row4_col2" class="data row4 col2" >-0.29</td>
#       <td id="T_4d072_row4_col3" class="data row4 col3" >0.00</td>
#       <td id="T_4d072_row4_col4" class="data row4 col4" >1.08</td>
#       <td id="T_4d072_row4_col5" class="data row4 col5" >0.30</td>
#       <td id="T_4d072_row4_col6" class="data row4 col6" >0.76</td>
#     </tr>
#     <tr>
#       <th id="T_4d072_level0_row5" class="row_heading level0 row5" >Saturday</th>
#       <td id="T_4d072_row5_col0" class="data row5 col0" >0.00</td>
#       <td id="T_4d072_row5_col1" class="data row5 col1" >0.64</td>
#       <td id="T_4d072_row5_col2" class="data row5 col2" >0.64</td>
#       <td id="T_4d072_row5_col3" class="data row5 col3" >0.48</td>
#       <td id="T_4d072_row5_col4" class="data row5 col4" >0.46</td>
#       <td id="T_4d072_row5_col5" class="data row5 col5" >0.30</td>
#       <td id="T_4d072_row5_col6" class="data row5 col6" >0.09</td>
#     </tr>
#     <tr>
#       <th id="T_4d072_level0_row6" class="row_heading level0 row6" >Sunday</th>
#       <td id="T_4d072_row6_col0" class="data row6 col0" >0.00</td>
#       <td id="T_4d072_row6_col1" class="data row6 col1" >0.05</td>
#       <td id="T_4d072_row6_col2" class="data row6 col2" >0.54</td>
#       <td id="T_4d072_row6_col3" class="data row6 col3" >-0.36</td>
#       <td id="T_4d072_row6_col4" class="data row6 col4" >0.06</td>
#       <td id="T_4d072_row6_col5" class="data row6 col5" >-0.33</td>
#       <td id="T_4d072_row6_col6" class="data row6 col6" >0.18</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Check typical % change in daily basis in each month

# %%
# Set pivot table based segregate based on month and day name, then calculate the mean aggregate
df4 = df.pivot_table(index=df.index.month_name(),
                     columns = df.index.day_name(),
                     fill_value = 0,
                     aggfunc = {'AdjC_pct':'mean'})

# Remove the first multi index column 
df4.columns = df4.columns.droplevel(0)

# Re-index based on monthscat
df4 = df4.T.reindex(columns=monthscat)

# Re-index based on dayscat
df4 = df4.T.reindex(columns=dayscat)

# Apply style
df4.style.applymap(above_zero).background_gradient(cmap='RdYlGn_r')
# Out:
# <style type="text/css">
# #T_09403_row0_col0, #T_09403_row1_col6, #T_09403_row2_col2, #T_09403_row2_col3, #T_09403_row2_col5, #T_09403_row7_col1, #T_09403_row10_col4 {
#   color: red;
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_09403_row0_col1 {
#   color: green;
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_09403_row0_col2 {
#   color: green;
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_09403_row0_col3 {
#   color: red;
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_09403_row0_col4 {
#   color: green;
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_09403_row0_col5 {
#   color: green;
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_09403_row0_col6 {
#   color: red;
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_09403_row1_col0 {
#   color: green;
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_09403_row1_col1 {
#   color: green;
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_09403_row1_col2 {
#   color: green;
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_09403_row1_col3 {
#   color: green;
#   background-color: #fee593;
#   color: #000000;
# }
# #T_09403_row1_col4, #T_09403_row3_col1, #T_09403_row3_col3, #T_09403_row6_col0, #T_09403_row9_col5, #T_09403_row9_col6, #T_09403_row10_col2, #T_09403_row11_col2 {
#   color: green;
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_09403_row1_col5, #T_09403_row2_col0 {
#   color: green;
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_09403_row2_col1 {
#   color: green;
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_09403_row2_col4 {
#   color: red;
#   background-color: #75c465;
#   color: #000000;
# }
# #T_09403_row2_col6 {
#   color: green;
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_09403_row3_col0 {
#   color: green;
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_09403_row3_col2 {
#   color: red;
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_09403_row3_col4 {
#   color: green;
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_09403_row3_col5 {
#   color: green;
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_09403_row3_col6, #T_09403_row4_col0 {
#   color: green;
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_09403_row4_col1 {
#   color: red;
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_09403_row4_col2 {
#   color: green;
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_09403_row4_col3 {
#   color: green;
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_09403_row4_col4 {
#   color: red;
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_09403_row4_col5 {
#   color: green;
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_09403_row4_col6, #T_09403_row10_col1 {
#   color: green;
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_09403_row5_col0 {
#   color: green;
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_09403_row5_col1 {
#   color: red;
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_09403_row5_col2 {
#   color: green;
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_09403_row5_col3 {
#   color: green;
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_09403_row5_col4 {
#   color: green;
#   background-color: #fee797;
#   color: #000000;
# }
# #T_09403_row5_col5 {
#   color: green;
#   background-color: #fed884;
#   color: #000000;
# }
# #T_09403_row5_col6 {
#   color: green;
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_09403_row6_col1, #T_09403_row10_col3 {
#   color: red;
#   background-color: #bde379;
#   color: #000000;
# }
# #T_09403_row6_col2 {
#   color: green;
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_09403_row6_col3 {
#   color: green;
#   background-color: #feda86;
#   color: #000000;
# }
# #T_09403_row6_col4 {
#   color: green;
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_09403_row6_col5 {
#   color: red;
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_09403_row6_col6 {
#   color: red;
#   background-color: #96d268;
#   color: #000000;
# }
# #T_09403_row7_col0 {
#   color: green;
#   background-color: #feca79;
#   color: #000000;
# }
# #T_09403_row7_col2 {
#   color: red;
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_09403_row7_col3, #T_09403_row9_col3 {
#   color: green;
#   background-color: #dd3d2d;
#   color: #f1f1f1;
# }
# #T_09403_row7_col4 {
#   color: green;
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_09403_row7_col5 {
#   color: green;
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_09403_row7_col6 {
#   color: red;
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_09403_row8_col0 {
#   color: green;
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_09403_row8_col1 {
#   color: red;
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_09403_row8_col2 {
#   color: green;
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_09403_row8_col3 {
#   color: red;
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_09403_row8_col4 {
#   color: green;
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_09403_row8_col5 {
#   color: green;
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_09403_row8_col6 {
#   color: red;
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_09403_row9_col0 {
#   color: green;
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_09403_row9_col1 {
#   color: green;
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_09403_row9_col2 {
#   color: green;
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_09403_row9_col4 {
#   color: green;
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_09403_row10_col0 {
#   color: green;
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_09403_row10_col5 {
#   color: red;
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_09403_row10_col6 {
#   color: green;
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_09403_row11_col0 {
#   color: green;
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_09403_row11_col1 {
#   color: green;
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_09403_row11_col3 {
#   color: green;
#   background-color: #c21c27;
#   color: #f1f1f1;
# }
# #T_09403_row11_col4 {
#   color: green;
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_09403_row11_col5 {
#   color: green;
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_09403_row11_col6 {
#   color: green;
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_09403_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="col_heading level0 col0" >Monday</th>
#       <th class="col_heading level0 col1" >Tuesday</th>
#       <th class="col_heading level0 col2" >Wednesday</th>
#       <th class="col_heading level0 col3" >Thursday</th>
#       <th class="col_heading level0 col4" >Friday</th>
#       <th class="col_heading level0 col5" >Saturday</th>
#       <th class="col_heading level0 col6" >Sunday</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09403_level0_row0" class="row_heading level0 row0" >January</th>
#       <td id="T_09403_row0_col0" class="data row0 col0" >-0.77</td>
#       <td id="T_09403_row0_col1" class="data row0 col1" >0.32</td>
#       <td id="T_09403_row0_col2" class="data row0 col2" >0.88</td>
#       <td id="T_09403_row0_col3" class="data row0 col3" >-1.07</td>
#       <td id="T_09403_row0_col4" class="data row0 col4" >0.36</td>
#       <td id="T_09403_row0_col5" class="data row0 col5" >1.11</td>
#       <td id="T_09403_row0_col6" class="data row0 col6" >-0.69</td>
#     </tr>
#     <tr>
#       <th id="T_09403_level0_row1" class="row_heading level0 row1" >February</th>
#       <td id="T_09403_row1_col0" class="data row1 col0" >0.91</td>
#       <td id="T_09403_row1_col1" class="data row1 col1" >0.93</td>
#       <td id="T_09403_row1_col2" class="data row1 col2" >0.41</td>
#       <td id="T_09403_row1_col3" class="data row1 col3" >0.16</td>
#       <td id="T_09403_row1_col4" class="data row1 col4" >1.31</td>
#       <td id="T_09403_row1_col5" class="data row1 col5" >0.55</td>
#       <td id="

# %%
# Apply style in transpose to reconfirm the pattern
df4.T.style.applymap(above_zero).background_gradient(cmap='RdYlGn_r')
# Out:
# <style type="text/css">
# #T_5a161_row0_col0 {
#   color: red;
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_5a161_row0_col1, #T_5a161_row3_col4 {
#   color: green;
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_5a161_row0_col2, #T_5a161_row0_col4, #T_5a161_row0_col6, #T_5a161_row1_col3, #T_5a161_row2_col10, #T_5a161_row2_col11, #T_5a161_row3_col5, #T_5a161_row4_col1, #T_5a161_row4_col7, #T_5a161_row4_col8, #T_5a161_row5_col0, #T_5a161_row5_col9 {
#   color: green;
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_5a161_row0_col3 {
#   color: green;
#   background-color: #dff293;
#   color: #000000;
# }
# #T_5a161_row0_col5 {
#   color: green;
#   background-color: #fee695;
#   color: #000000;
# }
# #T_5a161_row0_col7 {
#   color: green;
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_5a161_row0_col8 {
#   color: green;
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_5a161_row0_col9 {
#   color: green;
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_5a161_row0_col10, #T_5a161_row3_col6 {
#   color: green;
#   background-color: #93d168;
#   color: #000000;
# }
# #T_5a161_row0_col11, #T_5a161_row1_col9 {
#   color: green;
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_5a161_row1_col0 {
#   color: green;
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_5a161_row1_col1, #T_5a161_row1_col2 {
#   color: green;
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_5a161_row1_col4 {
#   color: red;
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_5a161_row1_col5, #T_5a161_row1_col7, #T_5a161_row2_col3, #T_5a161_row3_col0, #T_5a161_row3_col2, #T_5a161_row3_col8, #T_5a161_row4_col4, #T_5a161_row4_col10, #T_5a161_row6_col1, #T_5a161_row6_col6 {
#   color: red;
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_5a161_row1_col6 {
#   color: red;
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_5a161_row1_col8 {
#   color: red;
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_5a161_row1_col10 {
#   color: green;
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_5a161_row1_col11, #T_5a161_row2_col9 {
#   color: green;
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_5a161_row2_col0 {
#   color: green;
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_5a161_row2_col1 {
#   color: green;
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_5a161_row2_col2 {
#   color: red;
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_5a161_row2_col4 {
#   color: green;
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_5a161_row2_col5 {
#   color: green;
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_5a161_row2_col6 {
#   color: green;
#   background-color: #fed481;
#   color: #000000;
# }
# #T_5a161_row2_col7 {
#   color: red;
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_5a161_row2_col8 {
#   color: green;
#   background-color: #dd3d2d;
#   color: #f1f1f1;
# }
# #T_5a161_row3_col1 {
#   color: green;
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_5a161_row3_col3 {
#   color: green;
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_5a161_row3_col7 {
#   color: green;
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_5a161_row3_col9 {
#   color: green;
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_5a161_row3_col10 {
#   color: red;
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_5a161_row3_col11 {
#   color: green;
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_5a161_row4_col0 {
#   color: green;
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_5a161_row4_col2 {
#   color: red;
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_5a161_row4_col3 {
#   color: green;
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_5a161_row4_col5 {
#   color: green;
#   background-color: #be1827;
#   color: #f1f1f1;
# }
# #T_5a161_row4_col6 {
#   color: green;
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_5a161_row4_col9 {
#   color: green;
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_5a161_row4_col11 {
#   color: green;
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_5a161_row5_col1 {
#   color: green;
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_5a161_row5_col2 {
#   color: red;
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_5a161_row5_col3 {
#   color: green;
#   background-color: #addc6f;
#   color: #000000;
# }
# #T_5a161_row5_col4 {
#   color: green;
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_5a161_row5_col5 {
#   color: green;
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_5a161_row5_col6 {
#   color: red;
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_5a161_row5_col7 {
#   color: green;
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_5a161_row5_col8 {
#   color: green;
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_5a161_row5_col10 {
#   color: red;
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_5a161_row5_col11 {
#   color: green;
#   background-color: #c9e881;
#   color: #000000;
# }
# #T_5a161_row6_col0 {
#   color: red;
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# #T_5a161_row6_col2 {
#   color: green;
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_5a161_row6_col3 {
#   color: green;
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_5a161_row6_col4 {
#   color: green;
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_5a161_row6_col5 {
#   color: green;
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_5a161_row6_col7 {
#   color: red;
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_5a161_row6_col8 {
#   color: red;
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_5a161_row6_col9 {
#   color: green;
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_5a161_row6_col10 {
#   color: green;
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_5a161_row6_col11 {
#   color: green;
#   background-color: #a5d86a;
#   color: #000000;
# }
# </style>
# <table id="T_5a161_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="col_heading level0 col0" >January</th>
#       <th class="col_heading level0 col1" >February</th>
#       <th class="col_heading level0 col2" >March</th>
#       <th class="col_heading level0 col3" >April</th>
#       <th class="col_heading level0 col4" >May</th>
#       <th class="col_heading level0 col5" >June</th>
#       <th class="col_heading level0 col6" >July</th>
#       <th class="col_heading level0 col7" >August</th>
#       <th class="col_heading level0 col8" >September</th>
#       <th class="col_heading level0 col9" >October</th>
#       <th class="col_heading level0 col10" >November</th>
#       <th class="col_heading level0 col11" >December</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a161_level0_row0" class="row_heading level0 row0" >Monday</th>
#       <td id="T_5a161_row0_col0" class="data row0 col0" >-0.77</td>
#       <td id="T_5a161_row0_col1" class="data row0 col1" >0.91</td>
#       <td id="T_5a161_row0_col2" class="data row0 col2" >0.90</td>
#       <td id="T_5a161_row0_col3" class="data row0 col3" >0.75</td>
#       <td id="T_5a161_row0_col4" class="data row0 col4" >1.15</td>
#       <td id="T_5a161_row0_col5" class="data row0 col5" >0.22</td>
#       <td id="T_5a161_row0_col6" class="data row0 col6" >1.80</td>
#       <td id="T_5a161_row0_col7" class="data row0 col7" >0.88</td>
#       <td id="T_5a161_row0_col8" class="data row0 col8" >0.09</td>
#       <td id="T_5a161_row0_col9" class="data row0 col9" >0.45</td>
#       <td id="T_5a161_row0_col10" class="data row0 col10" >0.07</td>
#       <td id="T_5a161_row0_col11" class="data row0 col11" >0.11</td>
#     </tr>
#     <tr>
#       <th id="T_5a161_level0_row1" class="row_heading level0 row1" >Tuesday</th>
#       <td id="T_5a161_row1_col0" class="data row1 col0"

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Key insight:<br/>
# 1. <font color='green'>Sunday</font> is the lowest % price change.<br/>
# 2. Typically BTC volume transaction quite active during <font color='red'>weekdays</font> and slower on <font color='green'>weekend</font>.<br/>
# </div>

# %% [markdown]
# ### Check typical % change in date basis

# %%
# Groupby day name → find average → highlight on volume → set precision
df.groupby(df.index.day).mean().style.applymap(above_zero, subset=['AdjC_pct'])\
.bar(subset = ['Volume'])\
.format({'Adj Close': "{:.2f}",\
         'Volume': "{:.0f}",\
         'AdjC_pct': "{:.2f}",\
         'AdjC_cum': "{:.2f}"})\
.highlight_max()
# Out:
# <style type="text/css">
# #T_35592_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.8%, transparent 5.8%);
# }
# #T_35592_row0_col3, #T_35592_row1_col3, #T_35592_row2_col3, #T_35592_row4_col3, #T_35592_row5_col3, #T_35592_row6_col3, #T_35592_row7_col3, #T_35592_row8_col3, #T_35592_row12_col3, #T_35592_row15_col3, #T_35592_row16_col3, #T_35592_row17_col3, #T_35592_row18_col3, #T_35592_row22_col3, #T_35592_row25_col3, #T_35592_row26_col3, #T_35592_row27_col3, #T_35592_row28_col3, #T_35592_row29_col3, #T_35592_row30_col3 {
#   color: green;
# }
# #T_35592_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 16.6%, transparent 16.6%);
# }
# #T_35592_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 15.4%, transparent 15.4%);
# }
# #T_35592_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 16.3%, transparent 16.3%);
# }
# #T_35592_row3_col3, #T_35592_row9_col3, #T_35592_row10_col3, #T_35592_row11_col3, #T_35592_row13_col3, #T_35592_row14_col3, #T_35592_row20_col3, #T_35592_row21_col3, #T_35592_row23_col3, #T_35592_row24_col3 {
#   color: red;
# }
# #T_35592_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 17.6%, transparent 17.6%);
# }
# #T_35592_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 26.5%, transparent 26.5%);
# }
# #T_35592_row6_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 36.2%, transparent 36.2%);
# }
# #T_35592_row7_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 39.0%, transparent 39.0%);
# }
# #T_35592_row8_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 23.9%, transparent 23.9%);
# }
# #T_35592_row9_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 44.1%, transparent 44.1%);
# }
# #T_35592_row10_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 37.3%, transparent 37.3%);
# }
# #T_35592_row11_col1, #T_35592_row13_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 24.3%, transparent 24.3%);
# }
# #T_35592_row12_col1, #T_35592_row21_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 37.8%, transparent 37.8%);
# }
# #T_35592_row13_col0, #T_35592_row13_col2 {
#   background-color: yellow;
# }
# #T_35592_row14_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 26.7%, transparent 26.7%);
# }
# #T_35592_row15_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 34.2%, transparent 34.2%);
# }
# #T_35592_row16_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 31.4%, transparent 31.4%);
# }
# #T_35592_row17_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 22.3%, transparent 22.3%);
# }
# #T_35592_row18_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 32.8%, transparent 32.8%);
# }
# #T_35592_row19_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 34.3%, transparent 34.3%);
# }
# #T_35592_row19_col3 {
#   color: green;
#   background-color: yellow;
# }
# #T_35592_row20_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 36.6%, transparent 36.6%);
# }
# #T_35592_row22_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 41.3%, transparent 41.3%);
# }
# #T_35592_row23_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 26.2%, transparent 26.2%);
# }
# #T_35592_row24_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 16.5%, transparent 16.5%);
# }
# #T_35592_row25_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#   background-color: yellow;
# }
# #T_35592_row26_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 20.5%, transparent 20.5%);
# }
# #T_35592_row27_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 18.1%, transparent 18.1%);
# }
# #T_35592_row28_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 27.0%, transparent 27.0%);
# }
# #T_35592_row29_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 15.3%, transparent 15.3%);
# }
# #T_35592_row30_col1 {
#   width: 10em;
#   height: 80%;
# }
# </style>
# <table id="T_35592_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Adj Close</th>
#       <th class="col_heading level0 col1" >Volume</th>
#       <th class="col_heading level0 col2" >AdjC_cum</th>
#       <th class="col_heading level0 col3" >AdjC_pct</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35592_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_35592_row0_col0" class="data row0 col0" >10770.03</td>
#       <td id="T_35592_row0_col1" class="data row0 col1" >15076459516</td>
#       <td id="T_35592_row0_col2" class="data row0 col2" >10339.46</td>
#       <td id="T_35592_row0_col3" class="data row0 col3" >0.87</td>
#     </tr>
#     <tr>
#       <th id="T_35592_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_35592_row1_col0" class="data row1 col0" >10859.65</td>
#       <td id="T_35592_row1_col1" class="data row1 col1" >15776371434</td>
#       <td id="T_35592_row1_col2" class="data row1 col2" >10429.08</td>
#       <td id="T_35592_row1_col3" class="data row1 col3" >0.89</td>
#     </tr>
#     <tr>
#       <th id="T_35592_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_35592_row2_col0" class="data row2 col0" >10983.33</td>
#       <td id="T_35592_row2_col1" class="data row2 col1" >15693803410</td>
#       <td id="T_35592_row2_col2" class="data row2 col2" >10552.76</td>
#       <td id="T_35592_row2_col3" class="data row2 col3" >0.76</td>
#     </tr>
#     <tr>
#       <th id="T_35592_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_35592_row3_col0" class="data row3 col0" >10862.90</td>
#       <td id="T_35592_row3_col1" class="data row3 col1" >15755327346</td>
#       <td id="T_35592_row3_col2" class="data row3 col2" >10432.33</td>
#       <td id="T_35592_row3_col3" class="data row3 col3" >-0.19</td>
#     </tr>
#     <tr>
#       <th id="T_35592_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_35592_row4_col0" class="data row4 col0" >11049.78</td>
#       <td id="T_35592_row4_col1" class="data row4 col1" >15836977735</td>
#       <td id="T_35592_row4_col2" class="data row4 col2" >10619.21</td>
#       <td id="T_35592_row4_col3" class="data row4 col3" >0.71</td>
#     </tr>
#     <tr>
#       <th id="T_35592_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_35592_row5_col0" class="data row5 col0" >11176.84</td>
#       <td id="T_35592_row5_col1" class="data row5 col1" >16410939809</td>
#       <td id="T_35592_row5_col2" class="data row5 col2" >10746.27</td>
#       <td id="T_35592_row5_col3" class="data row5 col3" >0.87</td>
#     </tr>
#     <tr>
#       <th id="T_35592_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_35592_row6_col0" class="data row6 col0" >11169.70</td>
#       <td id="T_35592_row6_col1" class="data row6 col1" >17040328138</td>
#       <td id="T_35592_row6_col2" class="data row6 col2" >10739.13</td>
#       <td id="T_35592_row6_col3" class="data row6 col3" >0.36</td>
#     </tr>
#     <tr>
#       <th id="T_35592_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_35592_row7_col0" class="data row7 col0" >11286.08</td>
#       <td id="T_35592_row7_col1" class="data row7 col1" >17219016575</td>
#       <td id="T_35592_row7_col2" class="data row7 col2" >10855.51</td>
#       <td id="T_35592_row7_col3" class=

# %%
# Set pivot table based segregate based on year and date, then calculate the mean aggregate
df5 = df.pivot_table(index=df.index.year,
                     columns = df.index.day,
                     fill_value = 0,
                     aggfunc = {'AdjC_pct':'mean'})

# Remove the first multi index column 
df5.columns = df5.columns.droplevel(0)

# Apply style
df5.T.style.applymap(above_zero).background_gradient(cmap='RdYlGn_r')
# Out:
# <style type="text/css">
# #T_0a174_row0_col0, #T_0a174_row1_col0, #T_0a174_row2_col0, #T_0a174_row3_col0, #T_0a174_row4_col0, #T_0a174_row5_col0, #T_0a174_row6_col0, #T_0a174_row7_col0, #T_0a174_row8_col0, #T_0a174_row9_col0, #T_0a174_row10_col0, #T_0a174_row11_col0, #T_0a174_row11_col5, #T_0a174_row12_col0, #T_0a174_row13_col0, #T_0a174_row13_col2, #T_0a174_row14_col0, #T_0a174_row14_col1, #T_0a174_row15_col0, #T_0a174_row16_col0, #T_0a174_row17_col0, #T_0a174_row18_col0, #T_0a174_row19_col0, #T_0a174_row20_col0, #T_0a174_row20_col6, #T_0a174_row21_col0, #T_0a174_row21_col3, #T_0a174_row22_col0, #T_0a174_row23_col0, #T_0a174_row23_col4, #T_0a174_row24_col0, #T_0a174_row25_col0, #T_0a174_row26_col0, #T_0a174_row27_col0, #T_0a174_row28_col0, #T_0a174_row29_col0, #T_0a174_row30_col0 {
#   color: red;
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_0a174_row0_col1 {
#   color: green;
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_0a174_row0_col2, #T_0a174_row13_col5 {
#   color: green;
#   background-color: #fede89;
#   color: #000000;
# }
# #T_0a174_row0_col3 {
#   color: red;
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_0a174_row0_col4 {
#   color: green;
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_0a174_row0_col5 {
#   color: green;
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_0a174_row0_col6, #T_0a174_row5_col1, #T_0a174_row17_col5 {
#   color: green;
#   background-color: #fee797;
#   color: #000000;
# }
# #T_0a174_row1_col1 {
#   color: red;
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_0a174_row1_col2 {
#   color: green;
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_0a174_row1_col3, #T_0a174_row7_col6 {
#   color: green;
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# #T_0a174_row1_col4, #T_0a174_row12_col6, #T_0a174_row15_col1, #T_0a174_row19_col3, #T_0a174_row29_col5, #T_0a174_row30_col2 {
#   color: green;
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_0a174_row1_col5 {
#   color: red;
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_0a174_row1_col6, #T_0a174_row22_col3, #T_0a174_row26_col6 {
#   color: green;
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_0a174_row2_col1, #T_0a174_row7_col5, #T_0a174_row10_col3 {
#   color: red;
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_0a174_row2_col2, #T_0a174_row30_col6 {
#   color: green;
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_0a174_row2_col3 {
#   color: green;
#   background-color: #f99153;
#   color: #000000;
# }
# #T_0a174_row2_col4, #T_0a174_row11_col1, #T_0a174_row23_col5 {
#   color: green;
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_0a174_row2_col5 {
#   color: red;
#   background-color: #c9e881;
#   color: #000000;
# }
# #T_0a174_row2_col6, #T_0a174_row6_col4, #T_0a174_row27_col1 {
#   color: green;
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_0a174_row3_col1 {
#   color: green;
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_0a174_row3_col2 {
#   color: green;
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_0a174_row3_col3, #T_0a174_row20_col4 {
#   color: red;
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_0a174_row3_col4 {
#   color: red;
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_0a174_row3_col5 {
#   color: green;
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_0a174_row3_col6, #T_0a174_row14_col5, #T_0a174_row24_col5 {
#   color: red;
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_0a174_row4_col1 {
#   color: red;
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_0a174_row4_col2, #T_0a174_row25_col5 {
#   color: green;
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_0a174_row4_col3, #T_0a174_row16_col4 {
#   color: red;
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_0a174_row4_col4 {
#   color: green;
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_0a174_row4_col5 {
#   color: green;
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_0a174_row4_col6 {
#   color: green;
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_0a174_row5_col2 {
#   color: green;
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_0a174_row5_col3, #T_0a174_row13_col3 {
#   color: red;
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_0a174_row5_col4 {
#   color: green;
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_0a174_row5_col5, #T_0a174_row25_col6 {
#   color: green;
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_0a174_row5_col6, #T_0a174_row15_col5 {
#   color: green;
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_0a174_row6_col1, #T_0a174_row17_col1, #T_0a174_row25_col2 {
#   color: green;
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_0a174_row6_col2, #T_0a174_row19_col6 {
#   color: green;
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_0a174_row6_col3, #T_0a174_row24_col1 {
#   color: red;
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_0a174_row6_col5 {
#   color: green;
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_0a174_row6_col6, #T_0a174_row27_col6 {
#   color: red;
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_0a174_row7_col1 {
#   color: green;
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_0a174_row7_col2, #T_0a174_row17_col2 {
#   color: green;
#   background-color: #82c966;
#   color: #000000;
# }
# #T_0a174_row7_col3 {
#   color: red;
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_0a174_row7_col4 {
#   color: green;
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_0a174_row8_col1, #T_0a174_row8_col5, #T_0a174_row24_col6 {
#   color: red;
#   background-color: #98d368;
#   color: #000000;
# }
# #T_0a174_row8_col2 {
#   color: red;
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_0a174_row8_col3 {
#   color: green;
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_0a174_row8_col4 {
#   color: green;
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_0a174_row8_col6 {
#   color: green;
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_0a174_row9_col1 {
#   color: green;
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_0a174_row9_col2 {
#   color: red;
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_0a174_row9_col3 {
#   color: red;
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_0a174_row9_col4, #T_0a174_row17_col6 {
#   color: red;
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_0a174_row9_col5 {
#   color: red;
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_0a174_row9_col6 {
#   color: red;
#   background-color: #96d268;
#   color: #000000;
# }
# #T_0a174_row10_col1, #T_0a174_row16_col2 {
#   color: green;
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_0a174_row10_col2, #T_0a174_row12_col2 {
#   color: green;
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_0a174_row10_col4, #T_0a174_row13_col4, #T_0a174_row26_col4 {
#   color: red;
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_0a174_row10_col5, #T_0a174_row18_col1 {
#   color: red;
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_0a174_row10_col6, #T_0a174_row23_col1, #T_0a174_row30_col4 {
#   color: green;
#   background-color: #fed884;
#   color: #000000;
# }
# #T_0a174_row11_col2 {
#   color: green;
#   background-color: #addc6f;
#   color: #000000;
# }
# #T_0a174_row11_col3 {
#   color: green;
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_0a174_row11_col4, #T_0a174_row21_col6 {
#   color: green;
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_0a174_row11_col6, #T_0a174_row20_col2 {
#   color: red;
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_0a174_row12_col1 {
#   color: green;
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_0a174_row12_col3 {
#   color: red;
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_0a174_row12_col4, #T_0a174_row21_col4 {
#   color: green;
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_0a174_row12_col5 {
#   color: green;
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_0a174_row13_col1, #T_0a174_row14_col2 {
#   color: green;
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_0a174_row13_col6, #T_0a174_row22_col1 {
#   color: green;
#   background-color: #feca79;
#   color: #000000;
# }
# #T_0a174_row14_col3 {
#   color: green;
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_0a174_row14_col4 {
#   color: green;
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_0

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Key insight:<br/>
# 1. <font color='red'>Day 20</font> is the highest % price change.<br/>
# 2. <font color='green'>Day 10 and Day 21</font> is the lowest % price change.<br/>
# 3. <font color='magenta'>Day 26</font> is the day with highest volume transaction.<br/>
# </div>

# %% [markdown]
# ### Key Takeaway

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# General finding:<br/>
# 1. Typical BTC price % change is between <font color='black'>-2.8% to 3.4%</font>.<br/>
# 2. Highest BTC price % change is <font color='black'>25.2%</font> occur on Dec 12th, 2017.<br/>
# 3. Lowest BTC price % change is <font color='black'>-37.2%</font> occur on Mar 12th, 2020.<br/>
# 4. Typical volume transaction spans from <font color='black'>-300 million USD to 7 billion USD</font>.<br/>
# 5. Highest volume transaction is <font color='black'>350 billion USD</font> occur on Feb 26th, 2021.<br/>
# 6. Lowest volume transaction is <font color='black'>28 million USD</font> occur on May 5th, 2016.<br/>
#
# From month perspective:<br/>
# 7. <font color='blue'>March and September</font> is the month with lowest % price change.<br/>
# 8. <font color='red'>April and July</font> is the month with highest % price change.<br/>
# 9. BTC volume transaction typically active at the first half of the year.<br/>
# 10. No common pattern seen from BTC transaction since 2016 up to 2021.<br/>
# 11. <font color='red'>BTC price % pattern start change since 2020 onward</font>.<br/>
#
# From day perspective:<br/>
#
# 12. <font color='blue'>Sunday</font> is the lowest % price change.<br/>
# 13. Typically BTC volume transaction quite active during <font color='red'>weekdays</font> and slower on <font color='green'>weekend</font>.<br/>
#
# From date perspective:<br/>
# 14. <font color='red'>Day 20</font> is the highest % price change.<br/>
# 15. <font color='blue'>Day 10 and Day 21</font> is the lowest % price change.<br/>
# 16. <font color='magenta'>Day 26</font> is the day with highest volume transaction.<br/>
# </div>
