# %% [markdown]
# # Analysis single stock market price using yfinance module

# %%
# Upgrade the module 
# Ref: https://stackoverflow.com/questions/68320184/yfinance-returning-error-when-downloading-data
#!pip install yfinance --upgrade --no-cache-dir

# %%
import yfinance as yf
import pandas as pd

import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Set any float number precision 2 decimal points
pd.set_option('precision', 2)

# %%
start_date = '2016-01-01'
end_date = '2021-09-15'

# %%
# Extract stock price only 'Adj Close' and 'Volume'

df = yf.download('AAPL',start=start_date,end=end_date,interval='1d',rounding=1)[['Adj Close', 'Volume']]#.to_frame()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head(3)
# Out:
#             Adj Close     Volume
# Date
# 2015-12-31      24.27  163649200
# 2016-01-04      24.29  270597600
# 2016-01-05      23.68  223164000

# %%
# Define function for style
def above_zero(val):
  color = 'green' if val > 0 else 'red'
  return 'color: %s' % color

# %%
# Copy file to prevent A value is trying to be set on a copy of a slice from a DataFrame
df = df.copy()

# Find Adjusted Close price percentage
df.loc[:,'AdjC_pct'] = df.loc[:,'Adj Close'].pct_change()*100

# Fill NaN value with zero
df.fillna(value = 0, inplace = True)

# %% [markdown]
# ### Find typical price change %

# %%
df['AdjC_pct'].value_counts(bins = 5)
# Out:
# (-2.92, 2.051]      1233
# (2.051, 7.021]       132
# (-7.89, -2.92]        59
# (7.021, 11.991]        7
# (-12.886, -7.89]       5
# Name: AdjC_pct, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Key insight:<br/>
# Stock price typically change between -2.92% to 2%.
# </div>

# %%
# Highlight column 'AdjC_pct' and put bar on 'Volume'
df.sample(3).style.applymap(above_zero, subset=['AdjC_pct'])\
.bar(subset = ['Volume'])\
.format({'Adj Close': "{:.2f}",'AdjC_pct': "{:.2f}",'AdjC_cum': "{:.2f}"})\
.highlight_max()
# Out:
# <style  type="text/css" >
# #T_eb84e_row0_col1,#T_eb84e_row20_col1,#T_eb84e_row562_col1,#T_eb84e_row709_col1,#T_eb84e_row902_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.2%, transparent 24.2%);
#         }#T_eb84e_row0_col2,#T_eb84e_row2_col2,#T_eb84e_row3_col2,#T_eb84e_row4_col2,#T_eb84e_row8_col2,#T_eb84e_row10_col2,#T_eb84e_row11_col2,#T_eb84e_row13_col2,#T_eb84e_row15_col2,#T_eb84e_row17_col2,#T_eb84e_row20_col2,#T_eb84e_row21_col2,#T_eb84e_row24_col2,#T_eb84e_row26_col2,#T_eb84e_row27_col2,#T_eb84e_row28_col2,#T_eb84e_row32_col2,#T_eb84e_row33_col2,#T_eb84e_row35_col2,#T_eb84e_row39_col2,#T_eb84e_row44_col2,#T_eb84e_row45_col2,#T_eb84e_row52_col2,#T_eb84e_row54_col2,#T_eb84e_row56_col2,#T_eb84e_row57_col2,#T_eb84e_row58_col2,#T_eb84e_row61_col2,#T_eb84e_row64_col2,#T_eb84e_row66_col2,#T_eb84e_row72_col2,#T_eb84e_row73_col2,#T_eb84e_row74_col2,#T_eb84e_row76_col2,#T_eb84e_row77_col2,#T_eb84e_row78_col2,#T_eb84e_row79_col2,#T_eb84e_row80_col2,#T_eb84e_row81_col2,#T_eb84e_row82_col2,#T_eb84e_row83_col2,#T_eb84e_row85_col2,#T_eb84e_row86_col2,#T_eb84e_row87_col2,#T_eb84e_row90_col2,#T_eb84e_row91_col2,#T_eb84e_row94_col2,#T_eb84e_row96_col2,#T_eb84e_row102_col2,#T_eb84e_row103_col2,#T_eb84e_row104_col2,#T_eb84e_row105_col2,#T_eb84e_row109_col2,#T_eb84e_row111_col2,#T_eb84e_row112_col2,#T_eb84e_row114_col2,#T_eb84e_row116_col2,#T_eb84e_row117_col2,#T_eb84e_row119_col2,#T_eb84e_row121_col2,#T_eb84e_row122_col2,#T_eb84e_row127_col2,#T_eb84e_row133_col2,#T_eb84e_row135_col2,#T_eb84e_row139_col2,#T_eb84e_row140_col2,#T_eb84e_row141_col2,#T_eb84e_row142_col2,#T_eb84e_row145_col2,#T_eb84e_row147_col2,#T_eb84e_row153_col2,#T_eb84e_row154_col2,#T_eb84e_row157_col2,#T_eb84e_row158_col2,#T_eb84e_row159_col2,#T_eb84e_row161_col2,#T_eb84e_row163_col2,#T_eb84e_row164_col2,#T_eb84e_row165_col2,#T_eb84e_row166_col2,#T_eb84e_row167_col2,#T_eb84e_row171_col2,#T_eb84e_row173_col2,#T_eb84e_row174_col2,#T_eb84e_row179_col2,#T_eb84e_row180_col2,#T_eb84e_row181_col2,#T_eb84e_row182_col2,#T_eb84e_row184_col2,#T_eb84e_row188_col2,#T_eb84e_row190_col2,#T_eb84e_row198_col2,#T_eb84e_row200_col2,#T_eb84e_row201_col2,#T_eb84e_row202_col2,#T_eb84e_row203_col2,#T_eb84e_row204_col2,#T_eb84e_row207_col2,#T_eb84e_row208_col2,#T_eb84e_row209_col2,#T_eb84e_row210_col2,#T_eb84e_row211_col2,#T_eb84e_row213_col2,#T_eb84e_row214_col2,#T_eb84e_row217_col2,#T_eb84e_row218_col2,#T_eb84e_row220_col2,#T_eb84e_row223_col2,#T_eb84e_row227_col2,#T_eb84e_row229_col2,#T_eb84e_row230_col2,#T_eb84e_row231_col2,#T_eb84e_row232_col2,#T_eb84e_row234_col2,#T_eb84e_row239_col2,#T_eb84e_row241_col2,#T_eb84e_row247_col2,#T_eb84e_row250_col2,#T_eb84e_row251_col2,#T_eb84e_row252_col2,#T_eb84e_row254_col2,#T_eb84e_row260_col2,#T_eb84e_row261_col2,#T_eb84e_row263_col2,#T_eb84e_row264_col2,#T_eb84e_row267_col2,#T_eb84e_row270_col2,#T_eb84e_row271_col2,#T_eb84e_row272_col2,#T_eb84e_row274_col2,#T_eb84e_row280_col2,#T_eb84e_row284_col2,#T_eb84e_row288_col2,#T_eb84e_row293_col2,#T_eb84e_row295_col2,#T_eb84e_row297_col2,#T_eb84e_row298_col2,#T_eb84e_row301_col2,#T_eb84e_row304_col2,#T_eb84e_row306_col2,#T_eb84e_row308_col2,#T_eb84e_row309_col2,#T_eb84e_row313_col2,#T_eb84e_row314_col2,#T_eb84e_row317_col2,#T_eb84e_row318_col2,#T_eb84e_row319_col2,#T_eb84e_row320_col2,#T_eb84e_row321_col2,#T_eb84e_row323_col2,#T_eb84e_row325_col2,#T_eb84e_row326_col2,#T_eb84e_row328_col2,#T_eb84e_row331_col2,#T_eb84e_row333_col2,#T_eb84e_row336_col2,#T_eb84e_row337_col2,#T_eb84e_row341_col2,#T_eb84e_row344_col2,#T_eb84e_row345_col2,#T_eb84e_row346_col2,#T_eb84e_row350_col2,#T_eb84e_row351_col2,#T_eb84e_row353_col2,#T_eb84e_row355_col2,#T_eb84e_row358_col2,#T_eb84e_row361_col2,#T_eb84e_row362_col2,#T_eb84e_row363_col2,#T_eb84e_row365_col2,#T_eb84e_row366_col2,#T_eb84e_row367_col2,#T_eb84e_row369_col2,#T_eb84e_row371_col2,#T_eb84e_row373_col2,#T_eb84e_row374_col2,#T_eb84e_row376_col2,#T_eb84e_row378_col2,#T_eb84e_row380_col2,#T_eb84e_row390_col2,#T_eb84e_row391_col2,#T_eb84e_row395_col2,#T_eb84e_row396_col2,#T_eb84e_row397_col2,#T_eb84e_row400_col2,#T_eb84e_row405_col2,#T_eb84e_row409_col2,#T_eb84e_row410_col2,#T_eb84e_row411_col2,#T_eb84e_row412_col2,#T_eb84e_row415_col2,#T_eb84e_row422_col2,#T_eb84e_row ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Key insight:<br/>
# High volume transaction is an indication of price %change quite significant ↓ (or ↑) (might relate with any issue).
# </div>

# %%
# Create list of days category
dayscat = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Create list of months category
monthscat = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# %% [markdown]
# ### Check typical % change in monthly basis

# %%
# Groupby months name → find average → highlight on volume
df.groupby(df.index.month_name()).mean().reindex(monthscat).style.applymap(above_zero, subset=['AdjC_pct'])\
.format({'Adj Close': "{:.2f}",\
         'Volume': "{:.0f}",\
         'AdjC_pct': "{:.2f}",\
         'AdjC_cum': "{:.2f}"})\
.bar(subset = ['Volume'])
# Out:
# <style  type="text/css" >
# #T_89698_row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }#T_89698_row0_col2,#T_89698_row1_col2,#T_89698_row2_col2,#T_89698_row3_col2,#T_89698_row4_col2,#T_89698_row5_col2,#T_89698_row6_col2,#T_89698_row7_col2,#T_89698_row9_col2,#T_89698_row11_col2{
#             color:  green;
#         }#T_89698_row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 73.4%, transparent 73.4%);
#         }#T_89698_row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 92.2%, transparent 92.2%);
#         }#T_89698_row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 34.8%, transparent 34.8%);
#         }#T_89698_row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 50.3%, transparent 50.3%);
#         }#T_89698_row5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.4%, transparent 26.4%);
#         }#T_89698_row6_col1{
#             width:  10em;
#              height:  80%;
#         }#T_89698_row7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 37.8%, transparent 37.8%);
#         }#T_89698_row8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 88.4%, transparent 88.4%);
#         }#T_89698_row8_col2,#T_89698_row10_col2{
#             color:  red;
#         }#T_89698_row9_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 34.5%, transparent 34.5%);
#         }#T_89698_row10_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 48.9%, transparent 48.9%);
#         }#T_89698_row11_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 46.1%, transparent 46.1%);
#         }</style><table id="T_89698_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Adj Close</th>        <th class="col_heading level0 col1" >Volume</th>        <th class="col_heading level0 col2" >AdjC_pct</th>    </tr>    <tr>        <th class="index_name level0" >Date</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_89698_level0_row0" class="row_heading level0 row0" >January</th>
#                         <td id="T_89698_row0_col0" class="data row0 col0" >56.10</td>
#                         <td id="T_89698_row0_col1" class="data row0 col1" >152608096</td>
#                         <td id="T_89698_row0_col2" class="data row0 col2" >0.07</td>
#             </tr>
#             <tr>
#                         <th id="T_89698_level0_row1" class="row_heading level0 row1" >February</th>
#                         <td id="T_89698_row1_col0" class="data row1 col0" >57.01</td>
#                         <td id="T_89698_row1_col1" class="data row1 col1" >139114776</td>
#                         <td id="T_89698_row1_col2" class="data row1 col2" >0.04</td>
#             </tr>
#             <tr>
#                         <th id="T_89698_level0_row2" class="row_heading level0 row2" >March</th>
#                         <td id="T_89698_row2_col0" class="data row2 col0" >55.60</td>
#                         <td id="T_89698_row2_col1" class="data row2 col1" >148636659</td>
#                         <td id="T_89698_row2_col2" class="data row2 col2" >0.15</td>
#             </tr>
#             <tr>
#                         <th id="T_89698_level0_row3" class="row_heading level0 row3" >April</th>
#                         <td id="T_89698_row3_col0" class="data row3 col0" >58.24</td>
#                         <td id="T_89698_row3_col1" class="data row3 col1" >119572548</td>
#                         <td id="T_89698_row3_col2" class="data row3 col2" >0.10</td>
#             </tr>
#             <tr>
#                         <th id="T_89698_level0_row4" class="row_heading level0 row4" >May</th>
#                         <td id="T_89698_row4_col0" class="data row4 col0" >57.80</td>
#                         <td id="T_89698_row4_col1" class="data row4 col1" >127387525</td>
#                         <td id="T_89698_row4_col2" class="data row4 col2" >0.14</td>
#             </tr>
#             <tr>
#                         <th id="T_89698_level0_row5" class="row_heading level0 row5" >June</th>
#                         <td id="T_89698_row5_col0" class="data row5 col0" >61.33</td>
#                         <td id="T_89698_row5_col1" class="data row5 col1" >115318152</td>
#                         <td id="T_89698_row5_col2" class="data row5 col2" >0.20</td>
#             </tr>
#             <tr>
#                         <th id="T_89698_level0_row6" class="row_heading level0 row6" >July</th>
#                         <td id="T_89698_row6_col0" class="data row6 col0" >66.38</td>
#                         <td id="T_89698_row6_col1" class="data row6 col1" >101909509</td>
#                         <td id="T_89698_row6_col2" class="data row6 col2" >0.36</td>
#             </tr>
#             <tr>
#                         <th id="T_89698_level0_row7" class="row_heading level0 row7" >August</th>
#                         <td id="T_89698_row7_col0" class="data row7 col0" >70.54</td>
#                         <td id="T_89698_row7_col1" class="data row7 col1" >121053710</td>
#                         <td id="T_89698_row7_col2" class="data row7 col2" >0.41</td>
#             </tr>
#             <tr>
#                         <th id="T_89698_level0_row8" class="row_heading level0 row8" >September</th>
#                         <td id="T_89698_row8_col0" class="data row8 col0" >65.16</td>
#                         <td id="T_89698_row8_col1" class="data row8 col1" >146732267</td>
#                         <td id="T_89698_row8_col2" class="data row8 col2" >-0.04</td>
#             </tr>
#             <tr>
#                         <th id="T_89698_level0_row9" class="row_heading level0 row9" >October</th>
#                         <td id="T_89698_row9_col0" class="data row9 col0" >58.60</td>
#                         <td id="T_89698_row9_col1" class="data row9 col1" >119384628</td>
#                         <td id="T_89698_row9_col2" class="data row9 col2" >0.11</td>
#             </tr>
#             <tr>
#                         <th id="T_89698_level0_row10" class="row_heading level0 row10" >November</th>
#                         <td id="T_89698_row10_col0" class="data row10 col0" >58.30</td>
#                         <td id="T_89698_row10_col1" class="data row10 col1" >126704684</td>
#                         <td id="T_89698_row10_col2" class="data row10 col2" >-0.02</td>
#             </tr>
#             <tr>
#                         <th id="T_89698_level0_row11" class="row_heading level0 row11" >December</th>
#                         <td id="T_89698_row11_col0" class="data row11 col0" >61.46</td>
#                         <td id="T_89698_row11_col1" class="data row11 col1" >125289862</td>
#                         <td id="T_89698_row11_col2" class="data row11 col2" >0.12</td>
#             </tr>
#     </tbody></table>

# %%
# Set pivot table based segregate based on year and month name, then calculate the mean aggregate
df2 = df.pivot_table(index=df.index.year,
                     columns = df.index.month_name(),
                     fill_value = 0,
                     aggfunc = {'AdjC_pct':'mean'})

# Remove the first multi index column 
df2.columns = df2.columns.droplevel(0)

# Re-index based on monthscat
df2 = df2.reindex(columns=monthscat)

# %%
df2.style.applymap(above_zero).background_gradient(cmap='RdYlGn_r')
# Out:
# <style  type="text/css" >
# #T_0c65c_row0_col0,#T_0c65c_row6_col0{
#             color:  red;
#             background-color:  #feefa3;
#             color:  #000000;
#         }#T_0c65c_row0_col1{
#             color:  red;
#             background-color:  #f7fcb4;
#             color:  #000000;
#         }#T_0c65c_row0_col2{
#             color:  red;
#             background-color:  #b5df74;
#             color:  #000000;
#         }#T_0c65c_row0_col3,#T_0c65c_row3_col0{
#             color:  red;
#             background-color:  #fafdb8;
#             color:  #000000;
#         }#T_0c65c_row0_col4{
#             color:  red;
#             background-color:  #feffbe;
#             color:  #000000;
#         }#T_0c65c_row0_col5{
#             color:  red;
#             background-color:  #9dd569;
#             color:  #000000;
#         }#T_0c65c_row0_col6,#T_0c65c_row1_col0,#T_0c65c_row1_col3,#T_0c65c_row2_col5,#T_0c65c_row3_col2,#T_0c65c_row3_col10,#T_0c65c_row3_col11,#T_0c65c_row4_col4,#T_0c65c_row4_col7,#T_0c65c_row5_col1,#T_0c65c_row5_col8,#T_0c65c_row5_col9{
#             color:  red;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_0c65c_row0_col7{
#             color:  red;
#             background-color:  #0c7f43;
#             color:  #f1f1f1;
#         }#T_0c65c_row0_col8{
#             color:  red;
#             background-color:  #feeda1;
#             color:  #000000;
#         }#T_0c65c_row0_col9,#T_0c65c_row6_col9{
#             color:  red;
#             background-color:  #bde379;
#             color:  #000000;
#         }#T_0c65c_row0_col10,#T_0c65c_row6_col10{
#             color:  red;
#             background-color:  #fdc372;
#             color:  #000000;
#         }#T_0c65c_row0_col11,#T_0c65c_row6_col11{
#             color:  red;
#             background-color:  #fff1a8;
#             color:  #000000;
#         }#T_0c65c_row1_col1{
#             color:  green;
#             background-color:  #f7fcb4;
#             color:  #000000;
#         }#T_0c65c_row1_col2,#T_0c65c_row2_col1,#T_0c65c_row3_col4,#T_0c65c_row4_col0,#T_0c65c_row4_col8,#T_0c65c_row4_col9,#T_0c65c_row5_col3,#T_0c65c_row5_col5,#T_0c65c_row5_col6,#T_0c65c_row5_col7,#T_0c65c_row5_col10,#T_0c65c_row5_col11{
#             color:  green;
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_0c65c_row1_col4{
#             color:  green;
#             background-color:  #f57547;
#             color:  #000000;
#         }#T_0c65c_row1_col5{
#             color:  red;
#             background-color:  #128a49;
#             color:  #000000;
#         }#T_0c65c_row1_col6{
#             color:  green;
#             background-color:  #fedc88;
#             color:  #000000;
#         }#T_0c65c_row1_col7{
#             color:  green;
#             background-color:  #42ac5a;
#             color:  #000000;
#         }#T_0c65c_row1_col8{
#             color:  green;
#             background-color:  #c01a27;
#             color:  #f1f1f1;
#         }#T_0c65c_row1_col9{
#             color:  green;
#             background-color:  #cdea83;
#             color:  #000000;
#         }#T_0c65c_row1_col10{
#             color:  red;
#             background-color:  #fee28f;
#             color:  #000000;
#         }#T_0c65c_row1_col11{
#             color:  green;
#             background-color:  #f99153;
#             color:  #000000;
#         }#T_0c65c_row2_col0{
#             color:  green;
#             background-color:  #d62f27;
#             color:  #f1f1f1;
#         }#T_0c65c_row2_col2{
#             color:  green;
#             background-color:  #fee593;
#             color:  #000000;
#         }#T_0c65c_row2_col3{
#             color:  green;
#             background-color:  #fbfdba;
#             color:  #000000;
#         }#T_0c65c_row2_col4{
#             color:  green;
#             background-color:  #f8864f;
#             color:  #000000;
#         }#T_0c65c_row2_col6{
#             color:  green;
#             background-color:  #75c465;
#             color:  #000000;
#         }#T_0c65c_row2_col7{
#             color:  green;
#             background-color:  #feffbe;
#             color:  #000000;
#         }#T_0c65c_row2_col8{
#             color:  red;
#             background-color:  #5ab760;
#             color:  #000000;
#         }#T_0c65c_row2_col9,#T_0c65c_row5_col0{
#             color:  green;
#             background-color:  #be1827;
#             color:  #f1f1f1;
#         }#T_0c65c_row2_col10{
#             color:  green;
#             background-color:  #fa9857;
#             color:  #000000;
#         }#T_0c65c_row2_col11{
#             color:  red;
#             background-color:  #f8fcb6;
#             color:  #000000;
#         }#T_0c65c_row3_col1,#T_0c65c_row6_col5{
#             color:  green;
#             background-color:  #f7814c;
#             color:  #000000;
#         }#T_0c65c_row3_col3{
#             color:  red;
#             background-color:  #ebf7a3;
#             color:  #000000;
#         }#T_0c65c_row3_col5{
#             color:  red;
#             background-color:  #7fc866;
#             color:  #000000;
#         }#T_0c65c_row3_col6{
#             color:  green;
#             background-color:  #5ab760;
#             color:  #000000;
#         }#T_0c65c_row3_col7{
#             color:  green;
#             background-color:  #e54e35;
#             color:  #000000;
#         }#T_0c65c_row3_col8{
#             color:  red;
#             background-color:  #fffab6;
#             color:  #000000;
#         }#T_0c65c_row3_col9{
#             color:  red;
#             background-color:  #57b65f;
#             color:  #000000;
#         }#T_0c65c_row4_col1{
#             color:  green;
#             background-color:  #fdc171;
#             color:  #000000;
#         }#T_0c65c_row4_col2{
#             color:  green;
#             background-color:  #dd3d2d;
#             color:  #f1f1f1;
#         }#T_0c65c_row4_col3{
#             color:  green;
#             background-color:  #fdbb6c;
#             color:  #000000;
#         }#T_0c65c_row4_col5{
#             color:  green;
#             background-color:  #b10b26;
#             color:  #f1f1f1;
#         }#T_0c65c_row4_col6{
#             color:  green;
#             background-color:  #f2faae;
#             color:  #000000;
#         }#T_0c65c_row4_col10{
#             color:  green;
#             background-color:  #c62027;
#             color:  #f1f1f1;
#         }#T_0c65c_row4_col11{
#             color:  green;
#             background-color:  #bd1726;
#             color:  #f1f1f1;
#         }#T_0c65c_row5_col2{
#             color:  red;
#             background-color:  #54b45f;
#             color:  #000000;
#         }#T_0c65c_row5_col4{
#             color:  green;
#             background-color:  #e44c34;
#             color:  #000000;
#         }#T_0c65c_row6_col1{
#             color:  red;
#             background-color:  #39a758;
#             color:  #000000;
#         }#T_0c65c_row6_col2{
#             color:  green;
#             background-color:  #d9ef8b;
#             color:  #000000;
#         }#T_0c65c_row6_col3{
#             color:  green;
#             background-color:  #f99355;
#             color:  #000000;
#         }#T_0c65c_row6_col4{
#             color:  red;
#             background-color:  #9bd469;
#             color:  #000000;
#         }#T_0c65c_row6_col6{
#             color:  green;
#             background-color:  #e2f397;
#             color:  #000000;
#         }#T_0c65c_row6_col7{
#             color:  green;
#             background-color:  #82c966;
#             color:  #000000;
#         }#T_0c65c_row6_col8{
#             color:  red;
#             background-color:  #7ac665;
#             color:  #000000;
#         }</style><table id="T_0c65c_" ><thead>    <tr>        <th class="index_name level0" >Date</th>        <th class="col_heading level0 col0" >January</th>        <th class="col_heading level0 col1" >February</th>        <th class="col_heading level0 col2" >March</th>        <th class="col_heading level0 col3" >April</th>        <th class="col_heading level0 col4" >May</th>        <th class="col_heading level0 col5" >June</th>        <th class="col_heading level0 col6" >July</th>        <th class="col_heading level0 col7" >August</th>        <th class="col_heading level0 col8" >Se

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Key insight:<br/>
# 1. July and August is the month with highest % price change.<br/>
# 2. September is the month with lowest % price change.<br/>
# 3. January is the month with highest volume transaction.<br/>
# 4. July is the month with lowest volume transaction.<br/>
# </div>

# %% [markdown]
# ### Check typical % change in daily basis

# %%
# Groupby days name → find average → highlight on volume → set precision
df.groupby(df.index.day_name()).mean().reindex(dayscat).style\
.bar(subset = ['Volume'])\
.format({'Adj Close': "{:.2f}",\
         'Volume': "{:.0f}",\
         'AdjC_pct': "{:.2f}",\
         'AdjC_cum': "{:.2f}"})
# Out:
# <style  type="text/css" >
# #T_c0d4f_row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 17.3%, transparent 17.3%);
#         }#T_c0d4f_row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.0%, transparent 8.0%);
#         }#T_c0d4f_row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 29.0%, transparent 29.0%);
#         }#T_c0d4f_row3_col1{
#             width:  10em;
#              height:  80%;
#         }#T_c0d4f_row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }</style><table id="T_c0d4f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Adj Close</th>        <th class="col_heading level0 col1" >Volume</th>        <th class="col_heading level0 col2" >AdjC_pct</th>    </tr>    <tr>        <th class="index_name level0" >Date</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c0d4f_level0_row0" class="row_heading level0 row0" >Monday</th>
#                         <td id="T_c0d4f_row0_col0" class="data row0 col0" >60.81</td>
#                         <td id="T_c0d4f_row0_col1" class="data row0 col1" >126876300</td>
#                         <td id="T_c0d4f_row0_col2" class="data row0 col2" >0.32</td>
#             </tr>
#             <tr>
#                         <th id="T_c0d4f_level0_row1" class="row_heading level0 row1" >Tuesday</th>
#                         <td id="T_c0d4f_row1_col0" class="data row1 col0" >61.05</td>
#                         <td id="T_c0d4f_row1_col1" class="data row1 col1" >125759340</td>
#                         <td id="T_c0d4f_row1_col2" class="data row1 col2" >0.24</td>
#             </tr>
#             <tr>
#                         <th id="T_c0d4f_level0_row2" class="row_heading level0 row2" >Wednesday</th>
#                         <td id="T_c0d4f_row2_col0" class="data row2 col0" >60.63</td>
#                         <td id="T_c0d4f_row2_col1" class="data row2 col1" >128258469</td>
#                         <td id="T_c0d4f_row2_col2" class="data row2 col2" >0.23</td>
#             </tr>
#             <tr>
#                         <th id="T_c0d4f_level0_row3" class="row_heading level0 row3" >Thursday</th>
#                         <td id="T_c0d4f_row3_col0" class="data row3 col0" >60.53</td>
#                         <td id="T_c0d4f_row3_col1" class="data row3 col1" >124811812</td>
#                         <td id="T_c0d4f_row3_col2" class="data row3 col2" >-0.05</td>
#             </tr>
#             <tr>
#                         <th id="T_c0d4f_level0_row4" class="row_heading level0 row4" >Friday</th>
#                         <td id="T_c0d4f_row4_col0" class="data row4 col0" >60.06</td>
#                         <td id="T_c0d4f_row4_col1" class="data row4 col1" >136712512</td>
#                         <td id="T_c0d4f_row4_col2" class="data row4 col2" >-0.02</td>
#             </tr>
#             <tr>
#                         <th id="T_c0d4f_level0_row5" class="row_heading level0 row5" >Saturday</th>
#                         <td id="T_c0d4f_row5_col0" class="data row5 col0" >nan</td>
#                         <td id="T_c0d4f_row5_col1" class="data row5 col1" >nan</td>
#                         <td id="T_c0d4f_row5_col2" class="data row5 col2" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_c0d4f_level0_row6" class="row_heading level0 row6" >Sunday</th>
#                         <td id="T_c0d4f_row6_col0" class="data row6 col0" >nan</td>
#                         <td id="T_c0d4f_row6_col1" class="data row6 col1" >nan</td>
#                         <td id="T_c0d4f_row6_col2" class="data row6 col2" >nan</td>
#             </tr>
#     </tbody></table>

# %%
# Set pivot table based segregate based on year and month name, then calculate the mean aggregate
df3 = df.pivot_table(index=df.index.year,
                     columns = df.index.day_name(),
                     fill_value = 0,
                     aggfunc = {'AdjC_pct':'mean'})

# Remove the first multi index column 
df3.columns = df3.columns.droplevel(0)

# Re-index based on monthscat
df3 = df3.reindex(columns=dayscat)

# Fill NaN value with zero
df3.fillna(value = 0, inplace = True)

# Apply style
df3.style.applymap(above_zero).background_gradient(cmap='RdYlGn_r')
# Out:
# <style  type="text/css" >
# #T_63246_row0_col0{
#             color:  red;
#             background-color:  #17934e;
#             color:  #000000;
#         }#T_63246_row0_col1,#T_63246_row0_col5,#T_63246_row0_col6,#T_63246_row1_col3,#T_63246_row1_col5,#T_63246_row1_col6,#T_63246_row2_col5,#T_63246_row2_col6,#T_63246_row3_col0,#T_63246_row3_col4,#T_63246_row3_col5,#T_63246_row3_col6,#T_63246_row4_col5,#T_63246_row4_col6,#T_63246_row5_col5,#T_63246_row5_col6,#T_63246_row6_col2,#T_63246_row6_col5,#T_63246_row6_col6{
#             color:  red;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_63246_row0_col2{
#             color:  red;
#             background-color:  #9dd569;
#             color:  #000000;
#         }#T_63246_row0_col3{
#             color:  red;
#             background-color:  #fff8b4;
#             color:  #000000;
#         }#T_63246_row0_col4,#T_63246_row1_col4{
#             color:  red;
#             background-color:  #fdc171;
#             color:  #000000;
#         }#T_63246_row1_col0{
#             color:  green;
#             background-color:  #7ac665;
#             color:  #000000;
#         }#T_63246_row1_col1{
#             color:  green;
#             background-color:  #feec9f;
#             color:  #000000;
#         }#T_63246_row1_col2{
#             color:  green;
#             background-color:  #c3e67d;
#             color:  #000000;
#         }#T_63246_row2_col0{
#             color:  green;
#             background-color:  #fee18d;
#             color:  #000000;
#         }#T_63246_row2_col1{
#             color:  green;
#             background-color:  #c9e881;
#             color:  #000000;
#         }#T_63246_row2_col2{
#             color:  green;
#             background-color:  #f8fcb6;
#             color:  #000000;
#         }#T_63246_row2_col3{
#             color:  red;
#             background-color:  #0d8044;
#             color:  #f1f1f1;
#         }#T_63246_row2_col4{
#             color:  green;
#             background-color:  #ca2427;
#             color:  #f1f1f1;
#         }#T_63246_row3_col1{
#             color:  green;
#             background-color:  #93d168;
#             color:  #000000;
#         }#T_63246_row3_col2{
#             color:  green;
#             background-color:  #fdfebc;
#             color:  #000000;
#         }#T_63246_row3_col3,#T_63246_row4_col2,#T_63246_row4_col4,#T_63246_row5_col0,#T_63246_row5_col1{
#             color:  green;
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_63246_row4_col0{
#             color:  green;
#             background-color:  #b9e176;
#             color:  #000000;
#         }#T_63246_row4_col1{
#             color:  green;
#             background-color:  #cdea83;
#             color:  #000000;
#         }#T_63246_row4_col3{
#             color:  red;
#             background-color:  #f8fcb6;
#             color:  #000000;
#         }#T_63246_row5_col2{
#             color:  green;
#             background-color:  #fdaf62;
#             color:  #000000;
#         }#T_63246_row5_col3{
#             color:  red;
#             background-color:  #0e8245;
#             color:  #f1f1f1;
#         }#T_63246_row5_col4{
#             color:  red;
#             background-color:  #ebf7a3;
#             color:  #000000;
#         }#T_63246_row6_col0{
#             color:  green;
#             background-color:  #fafdb8;
#             color:  #000000;
#         }#T_63246_row6_col1{
#             color:  green;
#             background-color:  #33a456;
#             color:  #000000;
#         }#T_63246_row6_col3{
#             color:  green;
#             background-color:  #c41e27;
#             color:  #f1f1f1;
#         }#T_63246_row6_col4{
#             color:  green;
#             background-color:  #ed5f3c;
#             color:  #000000;
#         }</style><table id="T_63246_" ><thead>    <tr>        <th class="index_name level0" >Date</th>        <th class="col_heading level0 col0" >Monday</th>        <th class="col_heading level0 col1" >Tuesday</th>        <th class="col_heading level0 col2" >Wednesday</th>        <th class="col_heading level0 col3" >Thursday</th>        <th class="col_heading level0 col4" >Friday</th>        <th class="col_heading level0 col5" >Saturday</th>        <th class="col_heading level0 col6" >Sunday</th>    </tr>    <tr>        <th class="index_name level0" >Date</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_63246_level0_row0" class="row_heading level0 row0" >2015</th>
#                         <td id="T_63246_row0_col0" class="data row0 col0" >0.00</td>
#                         <td id="T_63246_row0_col1" class="data row0 col1" >0.00</td>
#                         <td id="T_63246_row0_col2" class="data row0 col2" >0.00</td>
#                         <td id="T_63246_row0_col3" class="data row0 col3" >0.00</td>
#                         <td id="T_63246_row0_col4" class="data row0 col4" >0.00</td>
#                         <td id="T_63246_row0_col5" class="data row0 col5" >0.00</td>
#                         <td id="T_63246_row0_col6" class="data row0 col6" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_63246_level0_row1" class="row_heading level0 row1" >2016</th>
#                         <td id="T_63246_row1_col0" class="data row1 col0" >0.13</td>
#                         <td id="T_63246_row1_col1" class="data row1 col1" >0.29</td>
#                         <td id="T_63246_row1_col2" class="data row1 col2" >0.07</td>
#                         <td id="T_63246_row1_col3" class="data row1 col3" >-0.20</td>
#                         <td id="T_63246_row1_col4" class="data row1 col4" >-0.00</td>
#                         <td id="T_63246_row1_col5" class="data row1 col5" >0.00</td>
#                         <td id="T_63246_row1_col6" class="data row1 col6" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_63246_level0_row2" class="row_heading level0 row2" >2017</th>
#                         <td id="T_63246_row2_col0" class="data row2 col0" >0.47</td>
#                         <td id="T_63246_row2_col1" class="data row2 col1" >0.19</td>
#                         <td id="T_63246_row2_col2" class="data row2 col2" >0.19</td>
#                         <td id="T_63246_row2_col3" class="data row2 col3" >-0.18</td>
#                         <td id="T_63246_row2_col4" class="data row2 col4" >0.18</td>
#                         <td id="T_63246_row2_col5" class="data row2 col5" >0.00</td>
#                         <td id="T_63246_row2_col6" class="data row2 col6" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_63246_level0_row3" class="row_heading level0 row3" >2018</th>
#                         <td id="T_63246_row3_col0" class="data row3 col0" >-0.08</td>
#                         <td id="T_63246_row3_col1" class="data row3 col1" >0.14</td>
#                         <td id="T_63246_row3_col2" class="data row3 col2" >0.20</td>
#                         <td id="T_63246_row3_col3" class="data row3 col3" >0.18</td>
#                         <td id="T_63246_row3_col4" class="data row3 col4" >-0.46</td>
#                         <td id="T_63246_row3_col5" class="data row3 col5" >0.00</td>
#                         <td id="T_63246_row3_col6" class="data row3 col6" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_63246_level0_row4" class="row_heading level0 row4" >2019</th>
#                         <td id="T_63246_row4_col0" class="data row4 col0" >0.23</td>
#                         <td id="T_63246_row4_col1" class="data row4 col1" >0.19</td>
#                         <td id="T_63246_row4_col2" class="data row4 col2" >0.68</td>
#                         <td id="T_63246_row4_col3" class="data row4 col3" >-0.02</td>
#                         <td id="T_63246_row4_col4" class="data row4 col4" >0.23</td>
#                         <td id="T_63246_row4_c

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Key insight:<br/>
# 1. Monday is the highest % price change.<br/>
# 2. Thursday is the lowest % price change.<br/>
# 3. Friday is the day with highest volume transaction.<br/>
# 4. Thursday is the day with lowest volume transaction.<br/>
# </div>

# %% [markdown]
# ### Check typical % change in week basis in a month

# %%
# Groupby weekday → find average → highlight on volume → set precision
df.groupby(df.index.weekday).mean().style.applymap(above_zero, subset=['AdjC_pct'])\
.bar(subset = ['Volume'])\
.format({'Adj Close': "{:.2f}",\
         'Volume': "{:.0f}",\
         'AdjC_pct': "{:.2f}",\
         'AdjC_cum': "{:.2f}"})
# Out:
# <style  type="text/css" >
# #T_44452_row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 17.3%, transparent 17.3%);
#         }#T_44452_row0_col2,#T_44452_row1_col2,#T_44452_row2_col2{
#             color:  green;
#         }#T_44452_row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.0%, transparent 8.0%);
#         }#T_44452_row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 29.0%, transparent 29.0%);
#         }#T_44452_row3_col1{
#             width:  10em;
#              height:  80%;
#         }#T_44452_row3_col2,#T_44452_row4_col2{
#             color:  red;
#         }#T_44452_row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }</style><table id="T_44452_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Adj Close</th>        <th class="col_heading level0 col1" >Volume</th>        <th class="col_heading level0 col2" >AdjC_pct</th>    </tr>    <tr>        <th class="index_name level0" >Date</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_44452_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_44452_row0_col0" class="data row0 col0" >60.81</td>
#                         <td id="T_44452_row0_col1" class="data row0 col1" >126876300</td>
#                         <td id="T_44452_row0_col2" class="data row0 col2" >0.32</td>
#             </tr>
#             <tr>
#                         <th id="T_44452_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_44452_row1_col0" class="data row1 col0" >61.05</td>
#                         <td id="T_44452_row1_col1" class="data row1 col1" >125759340</td>
#                         <td id="T_44452_row1_col2" class="data row1 col2" >0.24</td>
#             </tr>
#             <tr>
#                         <th id="T_44452_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_44452_row2_col0" class="data row2 col0" >60.63</td>
#                         <td id="T_44452_row2_col1" class="data row2 col1" >128258469</td>
#                         <td id="T_44452_row2_col2" class="data row2 col2" >0.23</td>
#             </tr>
#             <tr>
#                         <th id="T_44452_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_44452_row3_col0" class="data row3 col0" >60.53</td>
#                         <td id="T_44452_row3_col1" class="data row3 col1" >124811812</td>
#                         <td id="T_44452_row3_col2" class="data row3 col2" >-0.05</td>
#             </tr>
#             <tr>
#                         <th id="T_44452_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_44452_row4_col0" class="data row4 col0" >60.06</td>
#                         <td id="T_44452_row4_col1" class="data row4 col1" >136712512</td>
#                         <td id="T_44452_row4_col2" class="data row4 col2" >-0.02</td>
#             </tr>
#     </tbody></table>

# %%
# Set pivot table based segregate based on year and weekday name, then calculate the mean aggregate
df4 = df.pivot_table(index=df.index.month_name(),
                     columns = df.index.weekday,
                     aggfunc = {'AdjC_pct':'mean'})

# Remove the first multi index column 
df4.columns = df4.columns.droplevel(0)

# Re-index based on monthscat
df4 = df4.T.reindex(columns=monthscat)

# Fill NaN value with zero
df4.fillna(value = 0, inplace = True)

# Apply style
df4.style.applymap(above_zero).background_gradient(cmap='RdYlGn_r')
# Out:
# <style  type="text/css" >
# #T_e8e39_row0_col0,#T_e8e39_row0_col10,#T_e8e39_row1_col4,#T_e8e39_row2_col9,#T_e8e39_row3_col1,#T_e8e39_row3_col2,#T_e8e39_row4_col3,#T_e8e39_row4_col5,#T_e8e39_row4_col8,#T_e8e39_row4_col11{
#             color:  red;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_e8e39_row0_col1,#T_e8e39_row1_col8{
#             color:  green;
#             background-color:  #fed27f;
#             color:  #000000;
#         }#T_e8e39_row0_col2{
#             color:  green;
#             background-color:  #ddf191;
#             color:  #000000;
#         }#T_e8e39_row0_col3,#T_e8e39_row0_col4,#T_e8e39_row0_col7,#T_e8e39_row0_col8,#T_e8e39_row0_col9,#T_e8e39_row0_col11,#T_e8e39_row1_col2,#T_e8e39_row1_col5,#T_e8e39_row2_col1,#T_e8e39_row2_col6,#T_e8e39_row2_col10,#T_e8e39_row4_col0{
#             color:  green;
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_e8e39_row0_col5{
#             color:  green;
#             background-color:  #fed07e;
#             color:  #000000;
#         }#T_e8e39_row0_col6,#T_e8e39_row2_col7{
#             color:  green;
#             background-color:  #fedc88;
#             color:  #000000;
#         }#T_e8e39_row1_col0{
#             color:  green;
#             background-color:  #fdbf6f;
#             color:  #000000;
#         }#T_e8e39_row1_col1{
#             color:  green;
#             background-color:  #fecc7b;
#             color:  #000000;
#         }#T_e8e39_row1_col3{
#             color:  green;
#             background-color:  #f7fcb4;
#             color:  #000000;
#         }#T_e8e39_row1_col6{
#             color:  green;
#             background-color:  #279f53;
#             color:  #000000;
#         }#T_e8e39_row1_col7,#T_e8e39_row3_col6,#T_e8e39_row4_col7{
#             color:  green;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_e8e39_row1_col9,#T_e8e39_row2_col11{
#             color:  green;
#             background-color:  #fed884;
#             color:  #000000;
#         }#T_e8e39_row1_col10{
#             color:  red;
#             background-color:  #75c465;
#             color:  #000000;
#         }#T_e8e39_row1_col11{
#             color:  green;
#             background-color:  #fba05b;
#             color:  #000000;
#         }#T_e8e39_row2_col0{
#             color:  green;
#             background-color:  #f57245;
#             color:  #000000;
#         }#T_e8e39_row2_col2{
#             color:  red;
#             background-color:  #73c264;
#             color:  #000000;
#         }#T_e8e39_row2_col3{
#             color:  green;
#             background-color:  #e6f59d;
#             color:  #000000;
#         }#T_e8e39_row2_col4{
#             color:  green;
#             background-color:  #c21c27;
#             color:  #f1f1f1;
#         }#T_e8e39_row2_col5{
#             color:  green;
#             background-color:  #fafdb8;
#             color:  #000000;
#         }#T_e8e39_row2_col8{
#             color:  green;
#             background-color:  #fee593;
#             color:  #000000;
#         }#T_e8e39_row3_col0{
#             color:  red;
#             background-color:  #bbe278;
#             color:  #000000;
#         }#T_e8e39_row3_col3{
#             color:  green;
#             background-color:  #d1ec86;
#             color:  #000000;
#         }#T_e8e39_row3_col4{
#             color:  green;
#             background-color:  #e8f59f;
#             color:  #000000;
#         }#T_e8e39_row3_col5{
#             color:  red;
#             background-color:  #3ca959;
#             color:  #000000;
#         }#T_e8e39_row3_col7{
#             color:  green;
#             background-color:  #8ccd67;
#             color:  #000000;
#         }#T_e8e39_row3_col8{
#             color:  red;
#             background-color:  #17934e;
#             color:  #000000;
#         }#T_e8e39_row3_col9{
#             color:  green;
#             background-color:  #fdc776;
#             color:  #000000;
#         }#T_e8e39_row3_col10{
#             color:  green;
#             background-color:  #e24731;
#             color:  #f1f1f1;
#         }#T_e8e39_row3_col11{
#             color:  green;
#             background-color:  #fee08b;
#             color:  #000000;
#         }#T_e8e39_row4_col1{
#             color:  red;
#             background-color:  #70c164;
#             color:  #000000;
#         }#T_e8e39_row4_col2{
#             color:  green;
#             background-color:  #e3f399;
#             color:  #000000;
#         }#T_e8e39_row4_col4{
#             color:  green;
#             background-color:  #b30d26;
#             color:  #f1f1f1;
#         }#T_e8e39_row4_col6{
#             color:  green;
#             background-color:  #f99355;
#             color:  #000000;
#         }#T_e8e39_row4_col9{
#             color:  green;
#             background-color:  #fdc574;
#             color:  #000000;
#         }#T_e8e39_row4_col10{
#             color:  red;
#             background-color:  #63bc62;
#             color:  #000000;
#         }</style><table id="T_e8e39_" ><thead>    <tr>        <th class="index_name level0" >Date</th>        <th class="col_heading level0 col0" >January</th>        <th class="col_heading level0 col1" >February</th>        <th class="col_heading level0 col2" >March</th>        <th class="col_heading level0 col3" >April</th>        <th class="col_heading level0 col4" >May</th>        <th class="col_heading level0 col5" >June</th>        <th class="col_heading level0 col6" >July</th>        <th class="col_heading level0 col7" >August</th>        <th class="col_heading level0 col8" >September</th>        <th class="col_heading level0 col9" >October</th>        <th class="col_heading level0 col10" >November</th>        <th class="col_heading level0 col11" >December</th>    </tr>    <tr>        <th class="index_name level0" >Date</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e8e39_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e8e39_row0_col0" class="data row0 col0" >-0.42</td>
#                         <td id="T_e8e39_row0_col1" class="data row0 col1" >0.18</td>
#                         <td id="T_e8e39_row0_col2" class="data row0 col2" >0.15</td>
#                         <td id="T_e8e39_row0_col3" class="data row0 col3" >0.61</td>
#                         <td id="T_e8e39_row0_col4" class="data row0 col4" >0.23</td>
#                         <td id="T_e8e39_row0_col5" class="data row0 col5" >0.38</td>
#                         <td id="T_e8e39_row0_col6" class="data row0 col6" >0.44</td>
#                         <td id="T_e8e39_row0_col7" class="data row0 col7" >0.73</td>
#                         <td id="T_e8e39_row0_col8" class="data row0 col8" >0.67</td>
#                         <td id="T_e8e39_row0_col9" class="data row0 col9" >0.55</td>
#                         <td id="T_e8e39_row0_col10" class="data row0 col10" >-0.41</td>
#                         <td id="T_e8e39_row0_col11" class="data row0 col11" >0.52</td>
#             </tr>
#             <tr>
#                         <th id="T_e8e39_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e8e39_row1_col0" class="data row1 col0" >0.13</td>
#                         <td id="T_e8e39_row1_col1" class="data row1 col1" >0.19</td>
#                         <td id="T_e8e39_row1_col2" class="data row1 col2" >0.90</td>
#                         <td id="T_e8e39_row1_col3" class="data row1 col3" >0.10</td>
#                         <td id="T_e8e39_row1_col4" class="data row1 col4" >-0.03</td>
#                         <td id="T_e8e39_row1_col5" class="data row1 col5" >0.77</td>
#                         <td id="T_e8e39_row1_col6" class="data row1 col6" >0.09</td>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Key insight:<br/>
# 1. Mostly first week in every month is the highest % price change.<br/>
# 2. Mostly last week in every month is the lowest % price change.<br/>
# 3. Last week in a month typically record extreme max & min of volume transaction.<br/>
# </div>

# %% [markdown]
# ### Check typical % change in date basis

# %%
# Groupby day name → find average → highlight on volume → set precision
df.groupby(df.index.day).mean().style.applymap(above_zero, subset=['AdjC_pct'])\
.bar(subset = ['Volume'])\
.format({'Adj Close': "{:.2f}",\
         'Volume': "{:.0f}",\
         'AdjC_pct': "{:.2f}",\
         'AdjC_cum': "{:.2f}"})
# Out:
# <style  type="text/css" >
# #T_68260_row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 93.1%, transparent 93.1%);
#         }#T_68260_row0_col2,#T_68260_row1_col2,#T_68260_row3_col2,#T_68260_row4_col2,#T_68260_row5_col2,#T_68260_row6_col2,#T_68260_row7_col2,#T_68260_row8_col2,#T_68260_row10_col2,#T_68260_row11_col2,#T_68260_row12_col2,#T_68260_row13_col2,#T_68260_row14_col2,#T_68260_row15_col2,#T_68260_row20_col2,#T_68260_row21_col2,#T_68260_row23_col2,#T_68260_row24_col2,#T_68260_row25_col2,#T_68260_row27_col2,#T_68260_row28_col2,#T_68260_row29_col2,#T_68260_row30_col2{
#             color:  green;
#         }#T_68260_row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 88.3%, transparent 88.3%);
#         }#T_68260_row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 52.7%, transparent 52.7%);
#         }#T_68260_row2_col2,#T_68260_row9_col2,#T_68260_row16_col2,#T_68260_row17_col2,#T_68260_row18_col2,#T_68260_row19_col2,#T_68260_row22_col2,#T_68260_row26_col2{
#             color:  red;
#         }#T_68260_row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 58.0%, transparent 58.0%);
#         }#T_68260_row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 27.0%, transparent 27.0%);
#         }#T_68260_row5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 30.7%, transparent 30.7%);
#         }#T_68260_row6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 32.5%, transparent 32.5%);
#         }#T_68260_row7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 21.2%, transparent 21.2%);
#         }#T_68260_row8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 48.0%, transparent 48.0%);
#         }#T_68260_row9_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.0%, transparent 33.0%);
#         }#T_68260_row10_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.5%, transparent 31.5%);
#         }#T_68260_row11_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 68.3%, transparent 68.3%);
#         }#T_68260_row12_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 64.6%, transparent 64.6%);
#         }#T_68260_row13_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 51.3%, transparent 51.3%);
#         }#T_68260_row14_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 71.7%, transparent 71.7%);
#         }#T_68260_row15_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 49.3%, transparent 49.3%);
#         }#T_68260_row16_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.1%, transparent 28.1%);
#         }#T_68260_row17_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 23.5%, transparent 23.5%);
#         }#T_68260_row18_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 27.5%, transparent 27.5%);
#         }#T_68260_row19_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 56.5%, transparent 56.5%);
#         }#T_68260_row20_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 60.6%, transparent 60.6%);
#         }#T_68260_row21_col1{
#             width:  10em;
#              height:  80%;
#         }#T_68260_row22_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.5%, transparent 13.5%);
#         }#T_68260_row23_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.4%, transparent 20.4%);
#         }#T_68260_row24_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 22.7%, transparent 22.7%);
#         }#T_68260_row25_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 57.4%, transparent 57.4%);
#         }#T_68260_row26_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 78.6%, transparent 78.6%);
#         }#T_68260_row27_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 45.8%, transparent 45.8%);
#         }#T_68260_row28_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 46.4%, transparent 46.4%);
#         }#T_68260_row29_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 58.3%, transparent 58.3%);
#         }#T_68260_row30_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }</style><table id="T_68260_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Adj Close</th>        <th class="col_heading level0 col1" >Volume</th>        <th class="col_heading level0 col2" >AdjC_pct</th>    </tr>    <tr>        <th class="index_name level0" >Date</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_68260_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_68260_row0_col0" class="data row0 col0" >60.09</td>
#                         <td id="T_68260_row0_col1" class="data row0 col1" >146269718</td>
#                         <td id="T_68260_row0_col2" class="data row0 col2" >0.94</td>
#             </tr>
#             <tr>
#                         <th id="T_68260_level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_68260_row1_col0" class="data row1 col0" >62.54</td>
#                         <td id="T_68260_row1_col1" class="data row1 col1" >144432057</td>
#                         <td id="T_68260_row1_col2" class="data row1 col2" >0.22</td>
#             </tr>
#             <tr>
#                         <th id="T_68260_level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_68260_row2_col0" class="data row2 col0" >61.42</td>
#                         <td id="T_68260_row2_col1" class="data row2 col1" >130882548</td>
#                         <td id="T_68260_row2_col2" class="data row2 col2" >-0.23</td>
#             </tr>
#             <tr>
#                         <th id="T_68260_level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_68260_row3_col0" class="data row3 col0" >62.18</td>
#                         <td id="T_68260_row3_col1" class="data row3 col1" >132906750</td>
#                         <td id="T_68260_row3_col2" class="data row3 col2" >0.68</td>
#             </tr>
#             <tr>
#                         <th id="T_68260_level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_68260_row4_col0" class="data row4 col0" >59.24</td>
#                         <td id="T_68260_row4_col1" class="data row4

# %%
# Set pivot table based segregate based on year and month name, then calculate the mean aggregate
df5 = df.pivot_table(index=df.index.year,
                     columns = df.index.day,
                     fill_value = 0,
                     aggfunc = {'AdjC_pct':'mean'})

# Remove the first multi index column 
df5.columns = df5.columns.droplevel(0)

# Apply style
df5.T.style.applymap(above_zero).background_gradient(cmap='RdYlGn_r')
# Out:
# <style  type="text/css" >
# #T_08602_row0_col0,#T_08602_row1_col0,#T_08602_row2_col0,#T_08602_row2_col4,#T_08602_row3_col0,#T_08602_row4_col0,#T_08602_row5_col0,#T_08602_row6_col0,#T_08602_row7_col0,#T_08602_row8_col0,#T_08602_row9_col0,#T_08602_row10_col0,#T_08602_row11_col0,#T_08602_row12_col0,#T_08602_row13_col0,#T_08602_row14_col0,#T_08602_row15_col0,#T_08602_row15_col5,#T_08602_row16_col0,#T_08602_row17_col0,#T_08602_row17_col6,#T_08602_row18_col0,#T_08602_row19_col0,#T_08602_row19_col3,#T_08602_row20_col0,#T_08602_row21_col0,#T_08602_row22_col0,#T_08602_row22_col5,#T_08602_row23_col0,#T_08602_row24_col0,#T_08602_row25_col0,#T_08602_row26_col0,#T_08602_row26_col1,#T_08602_row27_col0,#T_08602_row28_col0,#T_08602_row28_col2,#T_08602_row29_col0,#T_08602_row30_col0{
#             color:  red;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_08602_row0_col1,#T_08602_row0_col5,#T_08602_row10_col1,#T_08602_row21_col2{
#             color:  green;
#             background-color:  #feefa3;
#             color:  #000000;
#         }#T_08602_row0_col2,#T_08602_row0_col3,#T_08602_row3_col4,#T_08602_row15_col1,#T_08602_row19_col6,#T_08602_row30_col5{
#             color:  green;
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_08602_row0_col4,#T_08602_row1_col5,#T_08602_row4_col6{
#             color:  green;
#             background-color:  #f7814c;
#             color:  #000000;
#         }#T_08602_row0_col6{
#             color:  green;
#             background-color:  #c01a27;
#             color:  #f1f1f1;
#         }#T_08602_row1_col1{
#             color:  red;
#             background-color:  #9bd469;
#             color:  #000000;
#         }#T_08602_row1_col2{
#             color:  green;
#             background-color:  #e65036;
#             color:  #000000;
#         }#T_08602_row1_col3,#T_08602_row2_col2{
#             color:  green;
#             background-color:  #f4fab0;
#             color:  #000000;
#         }#T_08602_row1_col4{
#             color:  red;
#             background-color:  #73c264;
#             color:  #000000;
#         }#T_08602_row1_col6{
#             color:  green;
#             background-color:  #fed683;
#             color:  #000000;
#         }#T_08602_row2_col1,#T_08602_row11_col3{
#             color:  green;
#             background-color:  #fdad60;
#             color:  #000000;
#         }#T_08602_row2_col3,#T_08602_row22_col6{
#             color:  green;
#             background-color:  #fdb567;
#             color:  #000000;
#         }#T_08602_row2_col5{
#             color:  red;
#             background-color:  #2da155;
#             color:  #000000;
#         }#T_08602_row2_col6{
#             color:  red;
#             background-color:  #e8f59f;
#             color:  #000000;
#         }#T_08602_row3_col1{
#             color:  green;
#             background-color:  #fee999;
#             color:  #000000;
#         }#T_08602_row3_col2{
#             color:  red;
#             background-color:  #7dc765;
#             color:  #000000;
#         }#T_08602_row3_col3,#T_08602_row16_col5,#T_08602_row29_col3{
#             color:  green;
#             background-color:  #fff7b2;
#             color:  #000000;
#         }#T_08602_row3_col5,#T_08602_row6_col6{
#             color:  green;
#             background-color:  #b50f26;
#             color:  #f1f1f1;
#         }#T_08602_row3_col6,#T_08602_row6_col4{
#             color:  red;
#             background-color:  #c7e77f;
#             color:  #000000;
#         }#T_08602_row4_col1{
#             color:  red;
#             background-color:  #0f8446;
#             color:  #f1f1f1;
#         }#T_08602_row4_col2,#T_08602_row5_col2{
#             color:  green;
#             background-color:  #cbe982;
#             color:  #000000;
#         }#T_08602_row4_col3,#T_08602_row26_col3,#T_08602_row28_col3{
#             color:  red;
#             background-color:  #abdb6d;
#             color:  #000000;
#         }#T_08602_row4_col4,#T_08602_row8_col5,#T_08602_row14_col2,#T_08602_row24_col2{
#             color:  green;
#             background-color:  #f2faae;
#             color:  #000000;
#         }#T_08602_row4_col5{
#             color:  green;
#             background-color:  #e14430;
#             color:  #f1f1f1;
#         }#T_08602_row5_col1{
#             color:  green;
#             background-color:  #fffdbc;
#             color:  #000000;
#         }#T_08602_row5_col3,#T_08602_row24_col4{
#             color:  green;
#             background-color:  #fff1a8;
#             color:  #000000;
#         }#T_08602_row5_col4,#T_08602_row25_col4{
#             color:  green;
#             background-color:  #fff6b0;
#             color:  #000000;
#         }#T_08602_row5_col5{
#             color:  green;
#             background-color:  #c21c27;
#             color:  #f1f1f1;
#         }#T_08602_row5_col6{
#             color:  red;
#             background-color:  #fafdb8;
#             color:  #000000;
#         }#T_08602_row6_col1,#T_08602_row19_col4,#T_08602_row22_col2{
#             color:  red;
#             background-color:  #91d068;
#             color:  #000000;
#         }#T_08602_row6_col2{
#             color:  green;
#             background-color:  #feeb9d;
#             color:  #000000;
#         }#T_08602_row6_col3{
#             color:  red;
#             background-color:  #82c966;
#             color:  #000000;
#         }#T_08602_row6_col5,#T_08602_row21_col3,#T_08602_row22_col4{
#             color:  red;
#             background-color:  #d5ed88;
#             color:  #000000;
#         }#T_08602_row7_col1,#T_08602_row16_col3{
#             color:  green;
#             background-color:  #fbfdba;
#             color:  #000000;
#         }#T_08602_row7_col2,#T_08602_row27_col2{
#             color:  green;
#             background-color:  #f8fcb6;
#             color:  #000000;
#         }#T_08602_row7_col3,#T_08602_row18_col1{
#             color:  red;
#             background-color:  #b5df74;
#             color:  #000000;
#         }#T_08602_row7_col4{
#             color:  green;
#             background-color:  #fffcba;
#             color:  #000000;
#         }#T_08602_row7_col5{
#             color:  green;
#             background-color:  #fee491;
#             color:  #000000;
#         }#T_08602_row7_col6{
#             color:  red;
#             background-color:  #e3f399;
#             color:  #000000;
#         }#T_08602_row8_col1{
#             color:  green;
#             background-color:  #f1f9ac;
#             color:  #000000;
#         }#T_08602_row8_col2{
#             color:  red;
#             background-color:  #6bbf64;
#             color:  #000000;
#         }#T_08602_row8_col3{
#             color:  green;
#             background-color:  #fca85e;
#             color:  #000000;
#         }#T_08602_row8_col4,#T_08602_row23_col2{
#             color:  green;
#             background-color:  #e0f295;
#             color:  #000000;
#         }#T_08602_row8_col6,#T_08602_row9_col5{
#             color:  green;
#             background-color:  #f26841;
#             color:  #000000;
#         }#T_08602_row9_col1{
#             color:  red;
#             background-color:  #93d168;
#             color:  #000000;
#         }#T_08602_row9_col2{
#             color:  red;
#             background-color:  #15904c;
#             color:  #000000;
#         }#T_08602_row9_col3,#T_08602_row26_col6{
#             color:  red;
#             background-color:  #c1e57b;
#             color:  #000000;
#         }#T_08602_row9_col4,#T_08602_row29_col6{
#             color:  green;
#             background-color:  #fee28f;
#             color:  #000000;
#         }#T_08602_row9_col6,#T_08602_row20_col3{
#             color:  red;
#             background-color:  #249d53;
#             color:  #000000;
#         }#T_08602_row10_col2,#T_08602_row30_col3{
#             color:  green;
#             background-color:  #f98e52;
#             color:  #000000;
#         }#T_08602_row10_col3,#T_08602_row20_col1{
#             color:  red;
#             background-color:  #e5f49b;
#             color:  #000000;
#         }#T_08602_row10_col4{
#             color:  green;
#             background-color:  #fdb96a;
#             color:  #000000;
#         }#T_08602_row10

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Key insight:<br/>
# 1. Day 1 and Day 15 is the highest % price change.<br/>
# 2. Day 19 and Day 27 is the lowest % price change.<br/>
# 3. Day 31 is the day with highest volume transaction.<br/>
# 4. Day 22 is the day with lowest volume transaction.<br/>
# </div>

# %% [markdown]
# ### Key Takeaway

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# General finding:<br/>
# 1. Stock price typically % change between -2.92% to 2%.<br/>
#
# From month perspective:<br/>
# 2. July and August seems the best month to harvest the profit.<br/>
# 3. September seems the best month to buy the stock (lowest % price change).<br/>
#
# From day perspective:<br/>
# 4. Monday is the highest % price change.<br/>
# 5. Thursday seems the best day to buy the stock (lowest % price change).<br/>
#
# From week in a month perspective:<br/>
# 6. Mostly first week in every month is the highest % price change.<br/>
# 7. Mostly last week in every month seems the best week to buy the stock (lowest % price change).<br/>
#
# From date perspective:<br/>
# 8. Day 1 and Day 15 is the highest % price change.<br/>
# 9. Day 19 and Day 27 probably the best date to buy the stock (lowest % price change).<br/>
# </div>
